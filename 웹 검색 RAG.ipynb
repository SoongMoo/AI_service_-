# %%
# !apt-get update
# !apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [99.9 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,816 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,106 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.5 MB]
# Hit:14 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,311 kB]
# Hit:16 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.6 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,619 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,332 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,089 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,614 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,425 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Fetched 43.5 MB in 4s (12.3 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 137 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 1s (491 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !nohup ollama serve >/dev/null 2>&1 &

# %%
# !ollama pull gemma3:4b

# %%
# !pip install -q ollama

# %%
# !pip install -q langchain-ollama

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(
    model="gemma3:4b",
    temperature=0.7
)
response = llm.invoke("대한민국 수도는?")
print(response.content)
# Out:
# 대한민국의 수도는 서울입니다.

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="gemma3:4b")
model.invoke("2025년 현대자동차 미국 시장 전망은 어떻게 되나요?")
# Out:
# AIMessage(content='2025년 현대자동차의 미국 시장 전망은 여러 요인에 따라 복합적으로 나타날 것으로 예상됩니다. 긍정적 측면과 부정적 측면을 모두 고려하여 상세히 분석해 보겠습니다.\n\n**긍정적인 요소:**\n\n*   **전기차 모델 출시 및 인기 증가**: 현대자동차는 2025년에는 이미 아이오닉 6와 같은 전기차 모델을 통해 미국 시장에 본격적으로 진출할 예정입니다. 특히, 아이오닉 6의 세련된 디자인과 뛰어난 주행 성능은 젊은 소비자층에게 어필하며 전기차 시장에서 점유율을 확대할 수 있을 것으로 예상됩니다. 또한, 현대자동차는 궁극적으로 롱레인지 모델(Long Range Model) 개발을 통해 전기차 시장에서의 경쟁력을 더욱 강화할 계획입니다.\n*   **소프트웨어 중심 자동차 (Software-defined Vehicle, SDV) 전략**: 현대자동차는 차량 소프트웨어를 통해 새로운 서비스와 기능을 제공하는 SDV 전략을 추진하며 고객 경험을 혁신하고 있습니다. 이를 통해 기존 내연기관차의 매력도를 높이는 동시에 전기차 시장에서 차별화된 가치를 제공할 수 있을 것으로 기대됩니다.\n*   **수요 변화에 대한 대응**: 미국 자동차 시장은 최근 SUV와 트럭에 대한 수요가 높은 편입니다. 현대자동차는 이러한 수요를 고려하여 팰리세이드(Palisade)와 싼타크루즈(Santa Cruz) 등과 같은 모델을 꾸준히 공급하며 소비자 선택의 폭을 넓힐 것입니다.\n*   **가격 경쟁력**: 미국 시장 가격 책정을 신중하게 결정하고, 전기차 모델의 경우 초기 보급형 모델을 통해 가격 경쟁력을 확보함으로써 소비자들의 관심을 끌 수 있을 것으로 예상됩니다.\n*   **미국 내 생산 능력 확대**: 현대자동차는 미국에 투자를 확대하여 생산 능력을 늘리고 있습니다. 이를 통해 물류 비용을 절감하고 고객에게 더 빠르고 효율적으로 제품을 공급할 수 있게 됩니다. 특히, 앨라배마 공장에 구축되는 새로운 전기차 공장은 현대자동차의 미래 성장 동력으로서 중요한 역할을 할 것입니다.\n\n**부정적인 요소:**\n\n*   **경기 침체 가능성**: 미국 경제는 고금리와 인플레이션 등의 영향으로 경기 침체 가능성이 높습니다. 이는 소비 심리를 위축시켜 자동차 판매량 감소로 이어질 수 있습니다.\n*   **전기차 경쟁 심화**: 전기차 시장은 테슬라를 비롯한 경쟁 업체들과의 치열한 경쟁이 예상됩니다. 테슬라는 뛰어난 브랜드 이미지와 충전 인프라를 바탕으로 시장 점유율을 더욱 확대할 가능성이 높습니다. 현대자동차는 테슬라와의 경쟁에서 승리하기 위해 지속적인 기술 개발과 투자, 그리고 차별화된 마케팅 전략을 추진해야 합니다.\n*   **내연기관차 판매 감소**: 미국 자동차 시장의 전반적인 트렌드는 전기차로 전환되는 추세입니다. 내연기관차 판매량이 감소함에 따라 현대자동차의 주력 모델 판매량도 영향을 받을 수 있습니다.\n*   **환율 변동**: 원/달러 환율 변동은 현대자동차의 미국 시장 수익성에 큰 영향을 미칠 수 있습니다.\n\n**종합적인 전망:**\n\n2025년 현대자동차는 전기차 모델 출시와 SDV 전략을 통해 미국 시장에서 성장 기회를 모색할 것입니다. 하지만, 경기 침체 가능성과 경쟁 심화 등 부정적인 요소도 존재하므로, 시장 상황 변화에 유연하게 대응하는 것이 중요합니다.\n\n**참고 자료:**\n\n*   [https://www.autonews.com/automakers/hyundai-motor-aims-boost-us-sales-electrified-vehicles](https://www.autonews.com/automakers/hyundai-motor-aims-boost-us-sales-electrified-vehicles)\n*   [https://www.greencarworld.com/news/50894/hyundai-ionic-6-us-launch-2023](https://www.greencarworld.com/news/50894/hyundai-ionic-6-us-launch-2023)\n\n**Disclaimer:** 위 내용은 현재까지 공개된 정보를 기반으로 한 분석이며, 실제 시장 상황은 예측과 다를 수 있습니다.', additional_kwargs={}, response_metadata={'model': 'gemma3:4b', 'created_at': '2026-07-14T08:26:57.047625776Z', 'done': True, 'done_reason': 'stop', 'total_duration': 119542440454, 'load_duration': 54516177719, 'prompt_eval_count': 25, 'prompt_eval_duration': 47103186000, 'eval_count': 937, 'eval_duration': 17920208000, 'logprobs': None, 'model_name': 'gemma3:4b', 'model_provider': 'ollama'}, id='lc_run--019f5fba-ad9c-7850-8a61-25f6ccfa9034-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 25, 'output_tokens': 937, 'total_tokens': 962})

# %%
# %pip install -U duckduckgo-search
# Out:
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (8.4.2)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-1.3.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (6.1.1)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading primp-1.3.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 71.6 MB/s eta 0:00:00
# Installing collected packages: primp, duckduckgo-search
# Successfully installed duckduckgo-search-8.1.1 primp-1.3.1

# %%
# %pip install -U ddgs # 무료인 경우 키를 발급 받지 않아도 되게
# Out:
# Collecting ddgs
#   Downloading ddgs-9.14.4-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from ddgs) (8.4.2)
# Requirement already satisfied: primp>=1.2.3 in /usr/local/lib/python3.12/dist-packages (from ddgs) (1.3.1)
# Requirement already satisfied: lxml>=4.9.4 in /usr/local/lib/python3.12/dist-packages (from ddgs) (6.1.1)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.2.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Downloading ddgs-9.14.4-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 2.9 MB/s eta 0:00:00
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 6.5 MB/s eta 0:00:00
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Installing collected packages: socksio, fake-useragent, ddgs
# Successfully installed ddgs-9.14.4 fake-useragent-2.2.0 socksio-1.0.0

# %%
# !pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.14.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.4.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.9.1)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.14.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.2)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.0)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 44.3 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 77.8 MB/s eta 0:00:00
# Downloading pydantic_settings-2.14.2-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 6.4 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 9.0 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: requests, httpx-sse, pydantic-settings, langchain-text-splitters, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-text-splitters-1.1.2 pydantic-settings-2.14.2 requests-2.34.2

# %%
from langchain_community.tools import DuckDuckGoSearchResults ### DuckDuckGo 검색창에 키워드를 쳤을 때 첫 페이지(혹은 상위 몇 개)에 나오는 결과만 긁어옵니다

search = DuckDuckGoSearchResults(results_separator=';\n')
docs = search.invoke("2025년 현대자동차 미국 시장 전망은 어떻게 되나요?")

print(docs)
# Out:
# /tmp/ipykernel_407/3869692663.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchResults
# snippet: Mar 4, 2026 ... 현대차는 2026년형 아이오닉 6의 미국 수출을 중단하기로 결정했습니다. 2025년형 재고가 소진되는 시점이 곧 미국시장에서의 마지막이 됩니다. 가장 큰 원인으로는 관세 ..., title: 이종민 | 현대자동차의 아이오닉 6가 미국 시장에서 사실상 단종 수순 ..., link: https://www.instagram.com/p/DVfoGPFkciw/;
# snippet: Apr 20, 2026 ... 현대자동차의 본업 수익성은 여전히 견고한 흐름을 유지하고 있습니다. 2025년 연간 매출액은 약 186조 원을 기록하며 전년 대비 6.3% 성장하는 기염을 토했습니다. 비록 ..., title: 현대자동차 주가 여전히 저평가, 여기까지 더 올라간다는데, link: https://m.blog.naver.com/ecoinfl/224258059119;
# snippet: Jan 18, 2026 ... 올해는 미국 시장이 침체 국면으로 전환됨에 따라 시장의 하방 압력을 극복하는 것이 관건이라는 분석이 제기된다. 한국자동차연구원은 최근 보고서에서 올해 미국 완성차 ..., title: 현대차그룹, 역대 최고 미국 시장 점유율 달성…2025년 183만대, 11.3, link: https://news.nate.com/view/20260118n04368;
# snippet: Sep 5, 2025 ... 현대차그룹이 도요타, 폴크스바겐에 이어 글로벌 판매 3위를 차지하는 주요한 원동력은 미국이다. 현재 미국에 판매되는 차량의 60~70%는 한국에서 생산된다. 현대차그룹은 ..., title: 현대차-GM 협력, 부평·창원·당진은 어떻게 될까 - 한겨레, link: https://www.hani.co.kr/arti/economy/economy_general/1217098.html

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

question_answering_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "사용자의 질문에 대해 아래 context에 기반하여 답변하라.:\n\n{context}",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)

document_chain = question_answering_prompt | model

# %%
from langchain_core.chat_history import InMemoryChatMessageHistory

# 채팅 메시지를 저장할 메모리 객체 생성
chat_history = InMemoryChatMessageHistory()

# 사용자 질문을 메모리에 저장
chat_history.add_user_message(
    "2025년 현대자동차 미국 시장 전망은 어떻게 되나요?"
)

# 문서 검색하고 답변 생성
answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 생성된 답변을 메모리에 저장
chat_history.add_ai_message(answer)

print(answer)
# Out:
# content='제공된 문맥을 바탕으로 2025년 현대자동차의 미국 시장 전망에 대한 정보를 요약하면 다음과 같습니다.\n\n*   **매출액:** 2025년 연간 매출액은 약 186조 원으로 전년 대비 6.3% 성장할 것으로 예상됩니다.\n*   **시장 점유율:** 현대차그룹은 역대 최고 수준의 미국 시장 점유율을 달성하여, 2025년에 183만 대를 판매하고 시장 점유율 11.3%를 기록할 것으로 보입니다.\n*   **침체 국면:** 올해는 미국 시장이 침체 국면에 접어들면서 하방 압력이 존재하며, 이를 극복하는 것이 중요한 과제로 인식되고 있습니다.\n*   **생산 및 판매 비중:** 현재 미국에 판매되는 차량의 60~70%가 한국에서 생산되며, 이 부분이 현대차그룹의 주요 동력으로 작용하고 있습니다.\n\n이러한 정보들을 종합해 볼 때, 2025년에는 어려운 시장 상황 속에서도 현대차그룹은 견조한 수익성을 바탕으로 미국 시장에서 높은 판매량을 기록할 것으로 예상됩니다. 하지만 침체 국면의 영향과 경쟁 심화라는 하방 요인을 고려해야 합니다.' additional_kwargs={} response_metadata={'model': 'gemma3:4b', 'created_at': '2026-07-14T08:29:32.429083919Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7372011315, 'load_duration': 1224435477, 'prompt_eval_count': 525, 'prompt_eval_duration': 380950000, 'eval_count': 284, 'eval_duration': 5655341000, 'logprobs': None, 'model_name': 'gemma3:4b', 'model_provider': 'ollama'} id='lc_run--019f5fbe-c2ba-7611-bbc5-322e450195d5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 525, 'output_tokens': 284, 'total_tokens': 809}

# %%
# DuckDuckGo API wrapper를 사용하여 검색할 때 검색 매개변수를 설정하기 위한 클래스 import
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper

# 한국 지역("kr-kr")을 기준, 최근 일주일("w") 내의 검색 결과를 가져오도록 초기화
wrapper = DuckDuckGoSearchAPIWrapper(region="kr-kr", time="w")

# %%
# 검색 기능을 위한 DuckDuckGoSearchResults 초기화
search = DuckDuckGoSearchResults(
    api_wrapper=wrapper,      # 앞에서 정의한 API wrapper를 사용
    source="news",            # 뉴스 소스에서만 검색하도록 지정
    results_separator=';\n'   # 결과 항목 사이에 구분자 사용 (세미콜론과 줄바꿈)
)

# %%
# "로제의 신곡 APT에 대한 반응"을 검색하고 결과를 docs에 저장
docs = search.invoke("2025년 현대자동차 미국 시장 전망은 어떻게 되나요?")

# 검색 결과 출력
print(docs)
# Out:
# snippet: 1 day ago · 현대자동차(Hyundai Motor Company) 완벽 분석: 강원도 통천군 소년의 꿈에서 세계 3위 자동차 제국까지 — 창립부터 2026년 현재까지 1. 서문: "이봐, 해봤어?"대한민국 경제 성장의 역사는 곧 현대자동차의 역사와 궤를 같이한다. 2026년 현재 현대자동차그룹은 글로벌 완성차 판매량 기준 세계 3위 자동차 ..., title: 현대자동차(Hyundai Motor Company) 완벽 분석: 강원도 통천군 소년의..., link: https://jackti.tistory.com/2534;
# snippet: 8 hours ago · 2026-07-09 현대자동차 현대차, '더 뉴 그랜저 테크 팝업 스토어' 행사 개최 2026-07-08 현대건설 현대건설, 나노 입자 기반 조강 콘크리트 기술 녹색인증 획득 2026-07-08 현대엔지니어링 현대엔지니어링, 미국 핵심광물 플랜트 시장 본격 진출 전체 3,486개, title: 뉴스룸: 공식 보도자료 | 현대자동차그룹, link: https://www.hyundaimotorgroup.com/ko/news/newsMain;
# snippet: 8 hours ago · [코리아포스트한글판 김정미 기자 ] 현대자동차 아이오닉 5가 미국 전기차(EV) 시장에서 테슬라를 제외한 브랜드 가운데 판매 1위에 오르며 글로벌 전기차 시장의, title: [이슈&분석] 아이오닉 5, 美 전기차 시장 '테슬라 대항마'로 부상…현..., link: https://www.koreapost.co.kr/news/articleView.html?idxno=87679;
# snippet: 8 hours ago · 현대자동차 아이오닉 5가 올해 상반기 미국 전기차 시장에서 판매 3위에 올라, 테슬라 모델 Y와 모델 3를 제외하면 가장 많이 팔린 전기차로, 미국 ..., title: 아이오닉 5, 미국서 테슬라 다음이었다…상반기 전기차 판매 3위 - 헤..., link: https://biz.heraldcorp.com/article/10808232

# %%
# DuckDuckGo를 이용해 ytn.co.kr 사이트에서 로제의 신곡 APT에 대한 내용을 검색
docs = search.invoke("site:ytn.co.kr 2025년 현대자동차 미국 시장 전망은 어떻게 되나요?")
docs
# Out:
# 'snippet: 우선 전국에 일자리를 100개 만들면 경기도에서 제가 8년 동안 전국 일자리의 43%를 경기도에서 다 만들었습니다. 그래서 저는 일자리 많이 만드는 일자리 대통령이 되겠습니다. 일자리는 어떻게 만드느냐., title: [현장영상+] 김문수 "현대 자동차 등 관세 피해 미국 가겠다 말해" | YTN, link: https://m.ytn.co.kr/news_view.php?key=202505251603320231&s_mcd=0101;\nsnippet: [앵커] SK하이닉스가 주력 제품인 고대역폭 메모리 \'HBM\'에 힘입어 1분기 \'깜짝 실적\'을 거뒀습니다. 25% 자동차 관세 부과로 부담이 큰 현대차도 1분기에는 선방했는데, 다가오는 2분기 전망은 밝지만은 않습니다., title: \'HBM의 힘\' SK하이닉스 깜짝 실적...현대차도 \'선방\' | YTN, link: https://m.ytn.co.kr/news_view.php?key=202504242235415079&s_mcd=0102;\nsnippet: 이에 따라 현대차그룹은 지난해 미국 시장 자동차 판매량에서 2023년에 이어 두 번째로 4위에 오르게 됐습니다. GM이 1위를 지켰고, 도요타가 2위, 3위는 포드였습니다., title: 현대차그룹, 지난해 미국 판매량 170만 대 역대 최다...2년 연속 톱4 | YTN, link: https://m.ytn.co.kr/news_view.php?key=202501052310200378&s_mcd=0102;\nsnippet: 이에 따라 현대차그룹은 지난해 미국 시장 자동차 판매량에서 2023년에 이어 두 번째로 4위에 오르게 됐습니다. GM이 1위를 지켰고, 도요타가 2위, 3위는 포드였습니다., title: 현대차그룹, 지난해 미국 판매량 170만 대 역대 최다...2년 연속 톱4 | YTN, link: https://m.ytn.co.kr/news_view.php?key=202501051434283101&s_mcd=0102'

# %%
# 검색 결과의 링크들을 저장할 빈 리스트 초기화
links = []

# 검색 결과를 세미콜론과 줄바꿈 기준으로 분리하고, 각 결과 항목에서 링크를 추출
for doc in docs.split(";\n"):
    print(doc)  # 각 검색 결과 항목을 출력하여 확인
    link = doc.split("link:")[1].strip()  # 각 항목에서 'link:' 이후의 URL 부분만 추출
    links.append(link)  # 추출한 링크를 리스트에 추가

# 모든 링크를 출력
print(links)
# Out:
# snippet: 우선 전국에 일자리를 100개 만들면 경기도에서 제가 8년 동안 전국 일자리의 43%를 경기도에서 다 만들었습니다. 그래서 저는 일자리 많이 만드는 일자리 대통령이 되겠습니다. 일자리는 어떻게 만드느냐., title: [현장영상+] 김문수 "현대 자동차 등 관세 피해 미국 가겠다 말해" | YTN, link: https://m.ytn.co.kr/news_view.php?key=202505251603320231&s_mcd=0101
# snippet: [앵커] SK하이닉스가 주력 제품인 고대역폭 메모리 'HBM'에 힘입어 1분기 '깜짝 실적'을 거뒀습니다. 25% 자동차 관세 부과로 부담이 큰 현대차도 1분기에는 선방했는데, 다가오는 2분기 전망은 밝지만은 않습니다., title: 'HBM의 힘' SK하이닉스 깜짝 실적...현대차도 '선방' | YTN, link: https://m.ytn.co.kr/news_view.php?key=202504242235415079&s_mcd=0102
# snippet: 이에 따라 현대차그룹은 지난해 미국 시장 자동차 판매량에서 2023년에 이어 두 번째로 4위에 오르게 됐습니다. GM이 1위를 지켰고, 도요타가 2위, 3위는 포드였습니다., title: 현대차그룹, 지난해 미국 판매량 170만 대 역대 최다...2년 연속 톱4 | YTN, link: https://m.ytn.co.kr/news_view.php?key=202501052310200378&s_mcd=0102
# snippet: 이에 따라 현대차그룹은 지난해 미국 시장 자동차 판매량에서 2023년에 이어 두 번째로 4위에 오르게 됐습니다. GM이 1위를 지켰고, 도요타가 2위, 3위는 포드였습니다., title: 현대차그룹, 지난해 미국 판매량 170만 대 역대 최다...2년 연속 톱4 | YTN, link: https://m.ytn.co.kr/news_view.php?key=202501051434283101&s_mcd=0102
# ['https://m.ytn.co.kr/news_view.php?key=202505251603320231&s_mcd=0101', 'https://m.ytn.co.kr/news_view.php?key=202504242235415079&s_mcd=0102', 'https://m.ytn.co.kr/news_view.php?key=202501052310200378&s_mcd=0102', 'https://m.ytn.co.kr/news_view.php?key=202501051434283101&s_mcd=0102']

# %%
# Langchain의 WebBaseLoader를 사용하여 웹 페이지의 내용을 불러옵니다.
from langchain_community.document_loaders import WebBaseLoader

# WebBaseLoader 객체를 생성. 'links'는 웹 페이지의 URL 목록을 담고 있는 변수
# bs_get_text_kwargs는 BeautifulSoup의 get_text() 메소드에 전달될 추가 인자
loader = WebBaseLoader(
    web_paths=links,  # 웹 페이지의 링크 목록을 지정
    bs_get_text_kwargs={
        "strip": True  # 웹 페이지에서 텍스트를 가져올 때 앞뒤의 공백을 제거
    },
)

# 비동기로 웹 페이지의 내용을 로드하고, 각 문서를 page_contents 리스트에 추가
page_contents = []  # 각 웹 페이지의 내용을 저장할 리스트입니다.
async for doc in loader.alazy_load():
    page_contents.append(doc)  # 불러온 문서를 page_contents 리스트에 추가

# page_contents에 있는 각 웹 페이지의 내용을 출력
for content in page_contents:
    print(content)  # 웹 페이지의 내용을 출력
    print('--------------')  # 페이지 구분을 위해 구분선을 출력
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# Fetching pages: 100%|##########| 4/4 [00:01<00:00,  2.63it/s]
# page_content='[현장영상+] 김문수 "현대 자동차 등 관세 피해 미국 가겠다 말해" | YTN전체메뉴YTN정치LIVE홈월드컵정치경제사회국제연예공유하기닫기이제 해당 작성자의 댓글 내용을확인할 수 없습니다.닫기신고하기광고 또는 스팸유언비어 및 욕설, 도배, 비방글사생활 침해 또는 명예훼손음란물닫기삭제하시겠습니까?이제 해당 댓글 내용을 확인할 수 없습니다[현장영상+] 김문수 "현대 자동차 등 관세 피해 미국 가겠다 말해"2025.05.25 오후 04:03글자 크기 설정글자 크기 설정닫기가가가가가공유하기AD[앵커]국민의힘 김문수 대선 후보는 휴일인 오늘, 충청권 곳곳을 누비며 표심을 호소하고 있습니다.충북 옥천 육영수 여사 생가 방문으로 일정을 시작해 충남 논산, 공주, 보령을 거쳐 홍성에 왔습니다.유세 현장 연결해 연설 들어보겠습니다.[김문수 / 국민의힘 대선 후보]여러분, 우리 강승규 국회의원이 이야기하신 것은 제가 전부 다 100% 다 틀림없이 하겠습니다.여러분, 이 홍성예산, 예산홍성은
건 재조명..."국산 우유는 품질관리 매우 엄격"공지사항개인정보처리방침이용약관청소년보호정책사업자정보PC버전Copyright Ⓒ YTN. All rights reserved.무단 전재, 재배포 및 AI 데이터 활용 금지' metadata={'source': 'https://m.ytn.co.kr/news_view.php?key=202501051434283101&s_mcd=0102', 'title': '현대차그룹, 지난해 미국 판매량 170만 대 역대 최다...2년 연속 톱4 | YTN', 'description': '현대차그룹이 지난해 미국 시장에서 역대 가장 많은 자동차를 팔면서 GM과 도요타, 포...', 'language': 'ko'}
# --------------

# %%
import requests
from bs4 import BeautifulSoup

# 주어진 URL에서 기사 텍스트를 가져오는 함수
def get_article_text(url):
    try:
        # URL에 GET 요청을 보냄
        response = requests.get(url)
        # 요청이 성공하지 못하면 예외를 발생시킴
        response.raise_for_status()

        # BeautifulSoup을 사용하여 HTML 내용을 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 클래스가 'story-news article'인 <article> 태그를 찾음
        article = soup.find('article', class_='story-news article')

        # 기사를 찾았다면 그 텍스트를 반환
        if article:
            return article.get_text(strip=True)
        else:
            try:
                if soup.find('article'):
                    return soup.find('article').get_text(strip=True)
                elif soup.find('div', id="CmAdContent"):
                    return soup.find('div', id="CmAdContent").get_text(strip=True)
            except:
                return "기사 내용을 찾을 수 없습니다."

    # 요청이 실패할 경우 예외 처리
    except requests.exceptions.RequestException as e:
        return f"URL을 가져오는 중 오류 발생: {e}"

# %%
# URL 목록의 각 링크를 반복하면서 기사 텍스트를 출력
articles = []    # 가져온 내용을 리스트에 담기 위한 변수 선언
for link in links:
    print(f"URL: {link}\n")
    article_text = get_article_text(link)
    print(f"Content:\n{article_text}")
    print("--------------------------------------------------")
    articles.append(article_text)
# Out:
# URL: https://m.ytn.co.kr/news_view.php?key=202505251603320231&s_mcd=0101
#
# Content:
# None
# --------------------------------------------------
# URL: https://m.ytn.co.kr/news_view.php?key=202504242235415079&s_mcd=0102
#
# Content:
# None
# --------------------------------------------------
# URL: https://m.ytn.co.kr/news_view.php?key=202501052310200378&s_mcd=0102
#
# Content:
# None
# --------------------------------------------------
# URL: https://m.ytn.co.kr/news_view.php?key=202501051434283101&s_mcd=0102
#
# Content:
# None
# --------------------------------------------------

# %%
chat_history.add_user_message("2025년 현대자동차 미국 시장 전망은 어떻게 되나요?")

# 문서 검색하고 답변을 생성
answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 생성된 답변 메모리에 저장
chat_history.add_ai_message(answer)
print(answer)
# Out:
# content='제공된 문맥에 따르면, 2025년 현대차그룹의 미국 시장 전망은 다음과 같습니다:\n\n*   **판매량:** 약 183만 대를 판매하며, 시장 점유율 11.3%를 기록할 것으로 예상됩니다.\n*   **전망:** 침체 국면에 접어든 미국 시장 상황을 고려했을 때 어려운 도전 과제가 존재합니다.' additional_kwargs={} response_metadata={'model': 'gemma3:4b', 'created_at': '2026-07-14T08:41:26.36616137Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8760334219, 'load_duration': 6474352591, 'prompt_eval_count': 935, 'prompt_eval_duration': 631038000, 'eval_count': 89, 'eval_duration': 1649274000, 'logprobs': None, 'model_name': 'gemma3:4b', 'model_provider': 'ollama'} id='lc_run--019f5fc9-a216-75f2-a626-55766f89e1d3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 935, 'output_tokens': 89, 'total_tokens': 1024}

# %%
# %pip install youtube-search
# Out:
# Collecting youtube-search
#   Downloading youtube_search-2.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from youtube-search) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-search) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-search) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-search) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-search) (2026.6.17)
# Downloading youtube_search-2.2.0-py3-none-any.whl (3.6 kB)
# Installing collected packages: youtube-search
# Successfully installed youtube-search-2.2.0

# %%
from youtube_search import YoutubeSearch

videos = YoutubeSearch("미국 대선", max_results=5).to_dict()
videos
# Out:
# [{'id': 'yUrKS8KldPk',
#   'thumbnails': ['https://i.ytimg.com/vi/yUrKS8KldPk/hqdefault.jpg?sqp=-oaymwEjCOADEI4CSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCXV5GBAOBgjsk55XCwjUmlZCl-gw'],
#   'title': '[Explained] 미국 대선, 어렵지 않아요!  / SBS',
#   'long_desc': None,
#   'channel': 'SBS 뉴스',
#   'duration': '5:12',
#   'views': '143,620 views',
#   'publish_time': '10 years ago',
#   'url_suffix': '/watch?v=yUrKS8KldPk&pp=ygUN66-46rWtIOuMgOyEoNIHCQlRCwGHKiGM7w%3D%3D'},
#  {'id': '4A3P9Tgm8wc',
#   'thumbnails': ['https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBiKa6FlGtJbPpVcHb4Nkfj_G7yqQ',
#    'https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA9dp_amuxkebdEB0E_Yg87rC4ZQA'],
#   'title': '[2020 US Presidential Election] Won Less, but Elected Anyways? / VIDEOMUG',
#   'long_desc': None,
#   'channel': '비디오머그 - VIDEOMUG',
#   'duration': '5:50',
#   'views': '520,650 views',
#   'publish_time': '5 years ago',
#   'url_suffix': '/watch?v=4A3P9Tgm8wc&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'kar-adwqkEc',
#   'thumbnails': ['https://i.ytimg.com/vi/kar-adwqkEc/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDSTnYm_3G3WXsQDdkayiChewy4zA',
#    'https://i.ytimg.com/vi/kar-adwqkEc/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLCKmqkBcALDOo3au-FAY_gvzZy3aQ'],
#   'title': '[미국대선 특보] \'2024 미국의 결정\' - 美 \'결전의 날\'…일부 지역 개표 시작 / 트럼프, 개표 초반 해리스 앞서 / CNN 출구조사는 "해리스 우세"',
#   'long_desc': None,
#   'channel': '뉴스TVCHOSUN',
#   'duration': '1:24:35',
#   'views': '1,881 views',
#   'publish_time': '1 year ago',
#   'url_suffix': '/watch?v=kar-adwqkEc&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'hjQUDizBA5U',
#   'thumbnails': ['https://i.ytimg.com/vi/hjQUDizBA5U/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAsT8mqyuww2ip-npejc6J1OC1eBA',
#    'https://i.ytimg.com/vi/hjQUDizBA5U/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDdyqF315S3UV35NJ2SzKfzuTaXzw'],
#   'title': '2020 미국 대선 상황실 / 연합뉴스TV (YonhapnewsTV)',
#   'long_desc': None,
#   'channel': '연합뉴스TV',
#   'duration': '4:37',
#   'views': '16,912 views',
#   'publish_time': '5 years ago',
#   'url_suffix': '/watch?v=hjQUDizBA5U&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'},
#  {'id': 'LKHzlzh7HBs',
#   'thumbnails': ['https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDeGBYbq18px6ES3r95qgC-rERrMg',
#    'https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLB4q1lp3LRY4-ASZp-U0YU5Dqq9dw'],
#   'title': "🇺🇸[미국대선특집] 대통령 선거 제도 '선거인단'의 유래와 역사",
#   'long_desc': None,
#   'channel': '조승연의 탐구생활',
#   'duration': '15:33',
#   'views': '1,260,728 views',
#   'publish_time': '5 years ago',
#   'url_suffix': '/watch?v=LKHzlzh7HBs&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'}]

# %%
# 경로 가져오기
video_url = 'http://youtube.com' + videos[3]['url_suffix']
video_url
# Out:
# 'http://youtube.com/watch?v=hjQUDizBA5U&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D'

# %%
# %pip install -U youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-1.2.4-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2026.6.17)
# Downloading youtube_transcript_api-1.2.4-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.2/485.2 kB 12.6 MB/s eta 0:00:00
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-1.2.4

# %%
# %pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
from langchain_community.document_loaders import YoutubeLoader
for v in videos:
    # url_suffix를 이용하여 video_url을 만듭니다.
    v['video_url'] = 'http://youtube.com' + v['url_suffix']

    # YoutubeLoader를 이용하여 비디오를 로드합니다.
    loader = YoutubeLoader.from_youtube_url(
        v['video_url'],
        language=['ko', 'en']
    )

    v['content'] = loader.load()

videos

# %%
for v in videos:
    # url_suffix를 이용하여 video_url을 만듭니다.
    v['video_url'] = 'http://youtube.com' + v['url_suffix']

    # YoutubeLoader를 이용하여 비디오를 로드합니다.
    loader = YoutubeLoader.from_youtube_url(
        v['video_url'],
        language=['ko', 'en']
    )

    v['content'] = loader.load()

videos

# %%
print('총 영상 수:', len(videos))
# 영상 길이가 60분 이하인 영상만 남깁니다.
videos = [v for v in videos if len(v['duration'].split(':')) < 3]
print('60분 이하 영상 수:', len(videos))
# Out:
# 총 영상 수: 5
# 60분 이하 영상 수: 4

# %%
# 랭체인, openai 임포트
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="gemma3:4b",
    temperature=0.7
)
model.invoke('안녕?') # 언어 모델이 잘 설정되었는지 테스트
# Out:
# AIMessage(content='안녕하세요! 무엇을 도와드릴까요? 😊\n', additional_kwargs={}, response_metadata={'model': 'gemma3:4b', 'created_at': '2026-07-14T08:44:54.203542357Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1915054603, 'load_duration': 1325836376, 'prompt_eval_count': 13, 'prompt_eval_duration': 90413000, 'eval_count': 11, 'eval_duration': 263784000, 'logprobs': None, 'model_name': 'gemma3:4b', 'model_provider': 'ollama'}, id='lc_run--019f5fcc-e8be-7bf0-b1c1-1a76a32c3a1b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 11, 'total_tokens': 24})

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser # 1. 출력 파서 추가

# 동영상 요약 프롬프트 작성
prompt = ChatPromptTemplate.from_messages(
    [("system", "다음 영상에 대한 요약을 한국어로 만들어줘 :\n\n{context}")]
)

# 2. 옛날 함수 대신 파이프(|)로 모델과 프롬프트를 연결합니다.
chain = prompt | model | StrOutputParser()

# 3. 원래 작성하셨던 방식 그대로 텍스트를 주입합니다.
result = chain.invoke({"context": videos[0]['content']})
print(result)
# Out:
# ## 미국 대선 과정 요약
#
# 이 영상에서는 미국의 독특한 대통령 선거 시스템인 “간접 선거”를 쉽게 설명합니다. 우리나라의 직접 선거 방식과는 달리, 미국에서는 국민들이 직접 대통령을 뽑는 것이 아니라 각 주에서 선출된 ‘선거인단’이 대통령을 선출합니다.
#
# **1. 경선 과정:**
#
# *   **대원 선거:** 각 정당은 먼저 대원을 선출하고, 이 대원들이 전당 대회에 모여 대통령 후보를 결정합니다.
# *   **코커스 & 프라이머리:** 대원 선출 방식은 크게 코커스와 프라이머리로 나뉩니다.
#     *   **코커스:** 정당 당원만 참여하는 회의입니다. (예: 아이오와, 뉴햄프셔)
#     *   **프라이머리:** 정당원이 아닌 일반 시민도 참여할 수 있는 방식입니다.
# *   **슈퍼 화요일:** 12개 주에서 동시에 프라이머리가 실시되는 날입니다. 이 결과가 경선 결과를 좌우합니다.
#
# **2. 전당 대회:** 경선에서 승리한 후보는 전당 대회를 통해 공식적으로 대통령 후보로 선정됩니다.
#
# **3. 본선 (선거인단 선출 & 대통령 선거):**
#
# *   각 당 후보들은 전국 각 주를 돌며 유권자들의 지지를 호소합니다.
# *   유권자들은 자신이 지지하는 후보에게 투표하지만, 투표 결과에 따라 해당 주의 모든 선거인단을 가져가는 ‘승자 독식’ 시스템이 적용됩니다.
# *   선거인단은 각 주의 인구수에 비례하여 배정되며, 선거인단 수 270명 이상을 확보한 후보가 대통령으로 당선됩니다.
#
# **특징:**
#
# *   미국 대선은 국민 투표 결과와 선거인단 투표 결과가 혼합되어 진행되므로, 국민 투표에서 승리하더라도 선거인단 투표에서 지면 대통령이 될 수 있습니다 (승자 독식 구조).
# *   아이오와 주와 뉴햄프셔 주에서의 경선 결과가 미국 대선 전체에 큰 영향을 미치는 것으로 알려져 있습니다.
#
# **결론:**
#
# 미국 대선은 복잡하지만, 선거인단 제도라는 특성상 각 주의 지지율을 확보하는 것이 중요하며, 국민 투표와 선거인단 투표 결과를 합산하여 대통령이 결정됩니다.

# %%
# 모든 비디오에 대해 요약을 생성
from tqdm import tqdm # tqdm은 진행 상황을 보여주는 라이브러리

for v in tqdm(videos):
    v['summary'] = chain.invoke({"context": v['content']})

videos
# Out:
# 100%|██████████| 4/4 [00:51<00:00, 12.96s/it]
# [{'id': 'yUrKS8KldPk',
#   'thumbnails': ['https://i.ytimg.com/vi/yUrKS8KldPk/hqdefault.jpg?sqp=-oaymwEjCOADEI4CSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCXV5GBAOBgjsk55XCwjUmlZCl-gw'],
#   'title': '[Explained] 미국 대선, 어렵지 않아요!  / SBS',
#   'long_desc': None,
#   'channel': 'SBS 뉴스',
#   'duration': '5:12',
#   'views': '143,620 views',
#   'publish_time': '10 years ago',
#   'url_suffix': '/watch?v=yUrKS8KldPk&pp=ygUN66-46rWtIOuMgOyEoNIHCQlRCwGHKiGM7w%3D%3D',
#   'video_url': 'http://youtube.com/watch?v=yUrKS8KldPk&pp=ygUN66-46rWtIOuMgOyEoNIHCQlRCwGHKiGM7w%3D%3D',
#   'content': [Document(metadata={'source': 'yUrKS8KldPk'}, page_content='힐러리와 트럼프 샌더스 요즘 국내 언론에도 자주 등장하는 이름들이죠. 2016년 미국은 지금 대통령 선거전이 한창입니다. 선거 당일 국민들이 직접 투표해서 대통령을 뽑는 직접 선거 방식인 우리나라와는 달리 미국 대선은 국민과 대통령 사이에 각 주위에서 선발된 선거인단이 깨어 있습니다. 국민은 선거 인단을 직접 뽑고 선거인단이 다시 대통령을 뽑는 간접 선거 방식입니다. 게다가 코우커스니, 프라이머리니 또 슈퍼 화이리니 하면서 생소한 용어가 나오다 보니 미국 대선을 두고 복잡하다, 잘 모르겠다 이렇게 생각하시는 분들 많으실 겁니다. 그래서 미국 대선 과정을 알기 �
때문에 미국의 대선에서는 국민의표를 더 바꿔도 대통령이 되지 못하는 아이러니한 일이 벌어지기도 하는데요. 실제로 지난 2000년 대선에선 보호민주당 후보가 도시 공화당 후보다 유권자로부터 54만 정도를 더 받았지만 대통령이 되지 못했습니다. 유권자 총표수는 적었지만 도시 후보가 승자 독식을 통해 선거인단수를 더 많이 확보해이긴 겁니다. 선거인단 선출이 끝나면이 선거인단이 다음 달엔 12월 대선 투표를 합니다. 결과에 이미 나왔지만 말입니다. 자, 1년 동안 펼쳐지는 다섯 복잡한 미국의 대선 과정이 좀 이해되셨나요? 국제정치와 경제, 군사적 측면 등 거의 전 방면에 걸쳐 초광대국인 미국의 위상으로 볼 때 미국의 대통령이 누가 되느냐는 지구촌의 관심사이기도 합니다. 오바마 대통령에 이어 미국의 제46대 대통령은 누가 될지 전 세계가 지켜보고 습니다.')],
#   'summary': '## 미국 대선 과정 요약\n\n이 영상에서는 미국의 독특한 대선 시스템을 쉽게 설명합니다. 우리나라와 달리, 미국 대선은 다음과 같은 특징을 가지고 있습니다.\n\n**1. 간접 선거:** 국민이 직접 대통령을 뽑는 대신, 각 주에서 선출된 선거인단이 대통령을 선출합니다.\n\n**2. 경선 과정 (프라이머리 & 코커스):**\n   * **각 당별 후보 선출:** 각 정당은 대의원들을 선출하고, 이들이 대통령 후보를 결정합니다.\n   * **코커스와 프라이머스:**\n      * **코커스:** 정당 지지자만 참여하는 당내 회의에서 대의원을 선출합니다 (아이오와, 뉴햄프셔 등 유명한 지역에서 진행).\n      * **프라이머스:** 일반 시민도 참여하여 대의원을 선출하는 방식입니다 (12개 주에서 화요일에 동시에 실시).\n   * **슈퍼 화요일:** 12개 주에서 프라이머스가 동시에 진행되는 날로, 각 후보의 지지율을 가늠할 수 있는 중요한 시점입니다.\n\n**3. 전당 대회:** 경선 과정에서 가장 많은 대의원을 얻은 후보가 당내 공식 후보로 선출됩니다.\n\n**4. 본선 (선거인단 선출 & 대통령 선거):**\n   * 각 후보는 전국을 돌며 유권자들의 지지를 호소합니다.\n   * 유권자들은 자신이 지지하는 후보에게 투표하여 선거인단을 얻습니다.\n   * 선거인단 수에 따라 대통령이 결정됩니다 (총 538명).\n   * **승자 독식:** 선거인단 수의 과반수(270명)를 확보한 후보가 대통령으로 당선됩니다.\n\n**5. 특이점:** 국민 투표 결과와 상관없이 선거인단 득표수에 따라 결정되므로, 국민 득표에서 패배해도 선거인단 득표수를 통해 대통령에 당선될 수 있습니다 (예: 2000년 대선).\n\n**결론적으로, 미국 대선은 복잡한 과정과 독특한 시스템을 가지고 있지만, 미국 정치의 중요한 부분을 차지하며 전 세계적인 관심사입니다.**'},
#  {'id': '4A3P9Tgm8wc',
#   'thumbnails': ['https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBiKa6FlGtJbPpVcHb4Nkfj_G7yqQ',
#    'https://i.ytimg.com/vi/4A3P9Tgm8wc/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA9dp_amuxkebdEB0E_Yg87rC4ZQA'],
#   'title': '[2020 US Presidential Election] Won Less, but Elected Anyways? / VIDEOMUG',
#   'long_desc': None,
#   'channel': '비디오머그 - VIDEOMUG',
#   'duration': '5:50',
#   'views': '520,650 views',
#   'publish_time': '5 years ago',
#   'url_suffix': '/watch?v=4A3P9Tgm8wc&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'video_url': 'http://youtube.com/watch?v=4A3P9Tgm8wc&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'content': [Document(metadata={'source
#  {'id': 'hjQUDizBA5U',
#   'thumbnails': ['https://i.ytimg.com/vi/hjQUDizBA5U/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAsT8mqyuww2ip-npejc6J1OC1eBA',
#    'https://i.ytimg.com/vi/hjQUDizBA5U/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDdyqF315S3UV35NJ2SzKfzuTaXzw'],
#   'title': '2020 미국 대선 상황실 / 연합뉴스TV (YonhapnewsTV)',
#   'long_desc': None,
#   'channel': '연합뉴스TV',
#   'duration': '4:37',
#   'views': '16,912 views',
#   'publish_time': '5 years ago',
#   'url_suffix': '/watch?v=hjQUDizBA5U&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'video_url': 'http://youtube.com/watch?v=hjQUDizBA5U&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'content': [Document(metadata={'source': 'hjQUDizBA5U'}, page_content='그 후보가 서로 승리를 주장하는 초유의 상황이 발생하면 섬이 대해서는 여전히 혼전 양상이 나타나고 있습니다 4 현장 투표에 대한 개표는 거의 마무리된 상황으로 보입니다 지금까지의 개표 상황 알아보겠습니다 이남기 앵커 네 미국 대선 개표 상황 전해드리겠습니다 자 먼저 두 후보의 전국 투표 상황 부터 살펴보도록 할텐데요 두 번의 전국 투표 상황은 어떻게 나오고 있는지 함께 알아보도록 하겠습니다 공화당의 도널드 트럼프 대통령 48.5% 민주당 의 조카 잊은 후보가 49.9% 로 전국 투표율은 쑥 바이든 후보가 약간 앞서고 있는 것으로 나타났습니다 자 그런데 중요한 건 건국 선거인단 확보 현황 2 겠어 미국 대통령의 방천 되기 위해선 최소 200 70명의 선거인단을 타코 해야하는데요 아 지금 보시면 트럼프 대통령이 200 13명 바이든 후보가 200 25명으로 파이드 후보가 약 12명 가량 앞두고 있는 것으로 나타났습니다 3 을 이번 대선의 승부처로 꼽혔던 경합 수 6곳을 살펴보도록 하겠습니다 먼 더 부풀어 트 벨트 테고 3 투표 상황인데요 이렇듯 벨트 적은 우편 투표 의 사전 작업을 허용하지 않기 때문에 개표가 지연되면서 승자를 아직 확정짓지 못하고 있습니다 4세 한번 보도록 하겠습니다 자 펜실베이니아주 같은 경우에는 트럼프 대통령이 55.7% 로 바이든 후보를 앞서가고 있고 미 시간과 미 스콘 50 역시 51.1% 51.1% 각각 득표 하면서 트럼프 대통령이 러스트 벨트 3곳 모두 앞서가고 있는 것으로 나타나 봅시당 짧은 에 남불 한번 가보시죠 남부 선 벨트 패고 퉁 에 두 곳에서는 이미 승부가 판가름 이 나왔습니다 트럼프 대통령이 플로리다에서 승리를 거뒀고 다이빙 후보가 애리조나에서 11명의 선거인단을 받고 있는데요 이것도 함께 자세히 보도록 하겠습니다 저희가 이렇게 노란색으로 체크를 표시 해 놨습니다 플로리 라 29명의 선거인단 에 걸려 있습니다 여기에서 트럼프 대통령이 51.8% 를 차지하면서 승리를 확정 지었고 애리조나 같은 경우에는 바이든 후보가 51.9% 로 이곳에서 승리를 확정 지었습니다 지금 노스캐롤라이나 같은 경우에는 아 트럼프 대통령 50.1% 파일은 후보 48.7% 로 아직 병 사업을 벌이고 있습니다 이렇게 봤을 때 6곳 중에 5 봇은 프루프 대통령이 앞두고 있는 것으로 나타나고 있습니다 자 그리고 격전지로 급부상할 포트로 예상했던 지역들은 결과를 어떻게 나왔을까요 기척 에서는 트럼프 대통령이 텍사스와 ioi 5 지금이 체크 해 드린 3곳에서 승리를 확정 지으면서 더 앞서나가는 양성 입니다 아 텍사스에 는 38명의 선거에 자지 걸려 있는데요 이곳에서 52.2% 를 트럼프 대통령이 득표 하면서 승리를 확정 지었고 요 ioio 역시 53% 이삭을 트럼프 대통령이 차지하면서 생기를 확정 기어 씁니다 조지아 같은 경우에는 트럼프 대통령 50.9% 다이드 부고 48.3% 로 이번 역시 트럼프 대통령이 앞서가고 있는 모습을 확인하실 수가 있습니다 이번 미국 대선에서는 상 하권 투표도 함께 진행이 됐습니다 어느 상의 먼저 의석 초에 바바 될 점이 해서 의회 권력을 차지하게 될까요 2년 임기 인 하원은 400 털은 5명 전원 의 유권자의 심판을 받았고 용연 인기인 상우는 전체 백석 가운데 35 서게 대해서 선거를 진행했습니다 공화당 같은 경우에는 기존 의석수 30석 의 17 썩을 확보하면서 47 석을 차지했고 민주당은 기존 의석수 33 서게 10 구석을 확보하면서 만 5석 을 차지했습니다 지금 이렇게만 보면 공화당 2만 7 속으로 과 반에 조금 더 가까운 모습을 확인할 수가 있습니다 하원 도 함께 보시죠 사원 총 400 30 5석 중에 공화당 대기를 5석 민주당 100여 등 5석 입니다 타원 에서는 민주당이 조금 더 과 반에 가까운 것으로 파악이 되고 있습니다 자 우레 대선에서는 특히나 사전투표 에 열기가 뜨거웠습니다 사전 투표를 완료한 유권자가 1억명을 넘어선 가운데 6000만 명 이상이 우편 투표 를 한 것으로 나타나 우편 토가 핵심 쟁점으로 떠오르고 있는데요 문제는 주마다 사전투표 에 개표 방식의 다른 데다가 우편 투표 가 급증하는 바람에 예년에 비해서 개표 완료 빠지는 훨씬 더 많은 시간이 필요할 것으로 보입니다 다 더욱이 경합 수인 가운데 경 합주 가운데 펜실베이니아 와 노스캐롤라이나 가 우편 투표 를 인정하는 도착 끼어들 각각 6일 12일까지 로 지정해 두었기 때문에 앞으로의 개표 상업을 계속해서 지켜봐야 할 것으로 보입니다 배선 관련해서 새로운 소식을 들어오는대로 다시 전해드리겠습니다 지금까지 대선 상황 실렸습니다')],
#   'summary': '## 미국 대통령 선거 개요 요약 (2024년)\n\n**핵심 결과:**\n\n*   **트럼프 vs 바이든, 치열한 경쟁**: 두 후보 간 전국 단위 투표에서 트럼프가 48.5%, 바이든이 49.9%로 매우 근접한 승부를 펼쳤습니다.\n*   **선거인단 확보는 트럼프 우위**: 현재까지 선거인단 확보 현황상 트럼프 후보가 바이든 후보보다 약 12명 이상 앞서고 있습니다. 이는 대통령 당선에 결정적인 영향을 미칠 수 있습니다.\n*   **러스트 벨트 지배**: 트럼프 후보가 펜실베이니아, 미 스콘진, 미시간 등 러스트 벨트의 주요 주에서 승리하며 유리한 고지를 점령했습니다.\n\n**주별 결과:**\n\n*   **남부 지역**: 트럼프 후보가 플로리다와 애리조나에서 승리했으며, 바이든 후보는 노스캐롤라이나에서 승리했습니다.\n*   **경합 주**: 텍사스, 아이오와 등 경합 주에서는 트럼프 후보가 압승을 거두었습니다.\n\n**하원 선거 결과:**\n\n*   **공화당 우위**: 하원의원 선거에서는 공화당이 기존 의석수보다 더 많은 석을 확보하며 과반  większość를 차지할 가능성이 높습니다.\n*   **민주당은 약세를**: 민주당 또한 일부 석을 확보했지만, 공화당에 비해 그 수가 적었습니다.\n\n**투표 방식 관련 이슈:**\n\n*   **우편 투표 지연**: 코로나19 팬데믹 이후 쏟아진 우편 투표로 인해 개표가 예상보다 훨씬 더 오래 지속될 것으로 보입니다. 특히, 주마다 우편 투표 인정 기간과 방식이 달라서 개표 결과에 변수가 될 수 있습니다.\n*   **사전 투표 열기**: 사전투표 참여율이 매우 높았으며, 이는 개표 지연의 주요 원인 중 하나입니다.\n\n**결론:**\n\n현재까지의 상황을 보면 트럼프 후보가 대통령 선거에서 승리할 가능성이 높은 것으로 보이지만, 우편 투표 결과에 따라 상황이 급변할 수 있습니다. 하원에서는 공화당이 과반  większość를 차지하며 여당 지배를 유지할 것으로 예상됩니다.'},
#  {'id': 'LKHzlzh7HBs',
#   'thumbnails': ['https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDeGBYbq18px6ES3r95qgC-rERrMg',
#    'https://i.ytimg.com/vi/LKHzlzh7HBs/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLB4q1lp3LRY4-ASZp-U0YU5Dqq9dw'],
#   'title': "🇺🇸[미국대선특집] 대통령 선거 제도 '선거인단'의 유래와 역사",
#   'long_desc': None,
#   'channel': '조승연의 탐구생활',
#   'duration': '15:33',
#   'views': '1,260,728 views',
#   'publish_time': '5 years ago',
#   'url_suffix': '/watch?v=LKHzlzh7HBs&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'video_url': 'http://youtube.com/watch?v=LKHzlzh7HBs&pp=ygUN66-46rWtIOuMgOyEoA%3D%3D',
#   'content': [Document(metadata={'source': 'LKHzlzh7HBs'}, page_content='안녕하세요 조승연 입니다 이제 11월 3일이 미국 대선이 줘 그러다 보니까 이제 많은 분들이 미국의 선거제도 에 대한 영상을 요청을 해 주셨어요 그래서 오늘은 미국의 굉장히 독특한 대통령선거 시스템인 선거인단 제도에 대한 영상을 한번 만들어봤습니다 이 미국대선 때가 되면은 이 대선 결과를 지켜보는 우리같은 외국인들은 물론이고 미국인들도 큰 혼란에 빠질 때가 많습니다 그 성제 미국의 대통령 선거 저도 이 선거인단 제도가 굉장히 복잡하기 때문이죠 이 선거인단 제도가 있기 때문에 대다수의 국민들의 표를 받은 사람이 대통령이 되지 못하는 경우가 미국 역사에서 5번 있었습니다 최근에 알고 와 힐러리 클린턴이 이런 방식으로 대통령 선거에서 떨어지게 되면서 사람들이 또 한번 선거인단 제도가 정확하게 뭐냐 이런 제도를 오해 가지고 있냐 미국이 이런거에 대해서 관심을 가지게 된거죠 미국의 독특한 정치 시스템을 이해하기 위해선 일단 미국에 이름을 보면 됩니다 2 우리가 미국을 이후 했어 유나 리 스 데이 쳐보면 할까 이렇게 불렀는데 리 제이윤 아리스 데이터 범해 할까라고 앞에 빚이라는 복수형 수식어를 사용을 하거든요 마치 나라가 하나가 아니라 여러 개가 있는 것처럼 얘기를 한다는 거죠 이 나라 이름이 왜 이런 식인 g 를 이해하기 위해서는 우리가 미국이 어떤 상황에서 건국일 했는지 그 건국 초기 로 돌아갈 필요가 있구요 그 건국 초기 스토리를 통해서 미국의 선거인단 제도를 이해할 수가 있는 거죠 일단 이 미국의 민주주의를 같다 이해하는 데 굉장히 도움이 되는 그 분석을 한 사람이 있습니다 알렉스 d 2b 일 이라고 하는 프랑스 외교관 이고요 미국의 민주주의라고 하는 미국 민주주의 의 역사에 관련된 책을 있었죠 프랑스의 민주주의와 미국의 민주주의 를 비교하는 내용이 있는데 그 내용이 미국을 이해하는 데 굉장히 큰 도움이 된다고 저는 생각을 해요 프랑스의 민주주의 같은 경우에는 이미 왕정이 공부하고 국가의 기틀이 만들어져 있는 나라에서 일어났기 때문에 그 왕이 가지고 있는 권한을 국민들이 다수결로 결정을 하는 방식으로 같다 그래서 결국 이 국가의 권력이 정부의 집중돼 있는 거에 대해서 사람들이 그 다 큰 불만을 제기하지 않고 그 정부의 결정권 자들을 내손으로 고를 수 있다는 것에 만족한다 이렇게 얘기합니다 미국 같은 경우에는 남의 간섭을 받기 가 얼마나 싫었는지 목숨을 걸고 배를 타고 대서양을 건너서 자 기대될 나름대로 공동체를 만들고 스스로 규율을 만들고 자유롭게 살아가던 여러 동네 들이 있는 그런 상황에서 출발을 했다는 거죠 그러다가 이제 동네가 따로따로 할 수 없는 큰 공동 프로젝트가 생기게 되면 자기네들 나름대로 주권을 가지고 있는 작은 공동체들이 중앙정부 라는 걸 만들어서 권력을 조금 때 지게 된다 라는 겁니다 즉 프랑스의 민주주의는 위해서 권력을 떼서 아래로 뿌리는 것이라면 미국의 민주주의는 아래에서 권력을 떼서 위로 살짝 모으는 형태로 진화를 했기 때문에 그 민주주의가 단어는 같을지 몰라도 본질적으로 형태와 정신이 같을 수 없다 라고 분석을 했어요 미국이 영국을 쫓아내고 독립을 이룬 다음에 이 13개 s 데이 스테이트 가 오늘 나는 주 라는 뜻으로 쓰이지만 원래는 국가라는 단어 잖아요 13개의 주권을 가진 스 데이트의 대표들이 힐라 될 거야 에 모여서 더 큰 공동체를 만들기 위해서 정관을 쓰는 작업을 하게 됩니다 이것이 바로 커스티 숀 컨벤션 이고 거기서 수많은 다른 이권과 다른 목표를 가지고 있는 여러 스테이 뜰이 동의를 할 수 있는 여러 협상을 통해서 만들어진 더 q 먼트 가 바로 오늘날 우리가 알고 있는 미국의 헌법 인 거예요 그런데 비슷한 시기에 만들어진 초기 민주 헌법 프랑스의 헌법과 미국 헌법을 비교해보면 느낌 자체가 굉장히 다릅니다 프랑스의 헌법은 이미 체계가 갖춰져 있는 국가의 원한을 왜 민중 한테 나누어 줘야 되는지 그리고 어떤 형태로 나눠줘야 되는지를 갔다가 정리한 이상적인 도큐먼트 