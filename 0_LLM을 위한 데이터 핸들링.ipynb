# %%
1. 텍스트 파일 읽기 (가장 기본)
# Out:
# 우리 회사의 근무 시간은 오전 9시부터 오후 6시까지입니다.
# 점심시간은 12시부터 1시까지입니다.

# %%
with open("company.txt", encoding="utf-8") as f:
    text = f.read()

print(text)
# Out:
# 우리 회사의 근무 시간은 오전 9시부터 오후 6시까지입니다.
# 점심시간은 12시부터 1시까지입니다.

# %%
2. CSV 데이터 처리

# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv("employee.csv")
df
# Out:
#      사번   이름  부서    연봉
# 0  1001  홍길동  개발  6000
# 1  1002  김철수  인사  5200

# %%
3. PDF 읽기

# %%
# !pip install PdfReader
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 1.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 1.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 988.0 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 988.0 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 988.0 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 988.0 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 988.0 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 988.0 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 988.0 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 466.0 kB/s eta 0:00:02
# ...

# %%
from pypdf import PdfReader

reader = PdfReader("과정기반 작물모형을 이용한 웹 기반 밀 재배관리 의사결정 지원시스템 설계 및 구축.pdf")

text = ""

for page in reader.pages:
    text += page.extract_text()
text
# Out:
# 'Journal of the Korean Society of Agricultural Engineers Vol. 66, No. 4, pp.17~26, July 2024\nDOI : https://doi.org/10.5389/KSAE.2024.66.4.017 ISSN 1738-3692 | eISSN 2093-7709\n한국농공학회논문집 제66권 제4호, 2024 • 17\n과정기반 작물모형을 이용한 웹 기반 밀 재배관리 의사결정 \n지원시스템 설계 및 구축\nDesign and Development of Web-Based Decision Support Systems for Wheat Management Practices \nUsing Process-Based Crop Model\n김솔희a⋅석승원b⋅청리광c⋅장태일d⋅김태곤e,†\nKim, Solhee⋅Seok, Seungwon⋅Cheng, Liguang⋅Jang, Taeil⋅Kim, Taegon\nABSTRACT\nThis study aimed to design and build a web-based decision support system for wheat cultivation management. The system is design ed to collect and \nmeasure the weather environment at the growth stage on a daily basis and predict the soil moisture content. Based on this, APSI M, one of the \nprocess-based crop models, was used to predict the potential yield of wheat cultivation in real time by making decisions at eac h stage. The \ndecision-making system for wheat crop management was designed to provide in
# ...

# %%
4. Word(docx) 읽기

# %%
# !pip install python-docx
# Out:
# ...
#   Using cached python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# ...
# Using cached python_docx-1.2.0-py3-none-any.whl (252 kB)
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 11.4 MB/s eta 0:00:01
#    ------- -------------------------------- 0.8/4.0 MB 11.4 MB/s eta 0:00:01
#    ------- -------------------------------- 0.8/4.0 MB 11.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/4.0 MB 1.1 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.1 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.1 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.1 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.1 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.1 MB/s eta 0:00:03
# ...

# %%
from docx import Document
doc = Document("guide.docx")
text = ""
for p in doc.paragraphs:
    text += p.text + "\n"
text
# Out:
# '안녕하세요. 어, 이 강의는 GPT API로 챗봇 만들기라는 내용을 다루는 강의입니다. 어, GPT API에 대해서 뭐 생소하신 분들도 있을 텐데, 어, 우리가 잘 알고 있는 챗 GPT, 챗 GPT를 이용해 챗 GPT 기능을 이용해서 어, 우리가 원하는 프로그램을 어떻게 만드는지에 대해서 어, 이야기할 거예요. 그래서 뭐 이런 강의들이 사실 많이 있습니다. 그래서 뭐 여러 가지들이 있는데 좀 이 강의의 특징이라고 한다면 이제 GPT로 명확한 미션을 달성하는 챗봇 프로그램을 만드는 게 사실 쉽지는 않은데 이거를 어떻게 해서 구현을 하는지 그리고 그게 왜 필요한지에 대해서 좀 이야기를 할 거고요. 어, 그 예제로 뭐 예전에 여러 가지가 될 수 있는데 여기서 예제로 하는 거는 음악 플레이리스트 동영상을 이제 자동으로 대화를 통해서 생성하는 프로그램을 만드는 거를 다루려고 합니다. 네, 그래서 프로그램이 실행되는 모습을 한번 보여 드릴게요. 그 우리가 그 만들 프로그램은 이런 식으로 이제 나타나게 될\n'

# %%
6. JSON 데이터

# %%
import json

with open("employee.json", encoding="utf-8") as f:
    data = json.load(f)

print(data)
# Out:
# {'name': '홍길동', 'department': '개발', 'salary': 6000}

# %%
7. 여러 문서를 하나로 합치기

# %%
import glob

texts = []

for file in glob.glob("*.txt"):
    with open(file, encoding="utf-8") as f:
        texts.append(f.read())

all_text = "\n".join(texts)
all_text
# Out:
# '우리 회사의 근무 시간은 오전 9시부터 오후 6시까지입니다.\n점심시간은 12시부터 1시까지입니다.\n# 과정기반 작물모형을 이용한 웹 기반 밀 재배관리 의사결정 지원시스템 설계 및 구축\n\n## 저자의 문제 인식 및 주장 (15문장 이내)\n\n한국은 밀 소비량이 지속적으로 증가함에도 불구하고 자급률이 1% 수준에 불과하여 안정적인 생산 기반 마련이 시급하다. 국내 밀의 가격 및 품질 경쟁력을 확보하고 단위면적당 생산량을 높이기 위해서는 체계적인 재배 및 관리가 필수적이다. 그러나 노지 재배 작물은 기상 환경 조절이 어렵고 돌발 재해, 병해충 피해, 토양 특성 차이 등 외부 요인에 의해 생산량에 큰 영향을 받는다. 기존의 농업 의사결정 지원 시스템은 대부분 시설원예에 초점을 맞춰 노지 작물의 급격한 생산량 저하를 막기 위한 실시간 환경 변화 및 시나리오 기반의 재배 관리 시스템이 부재한 실정이다.\n\n이에 저자들은 과정기반 작물모형인 APSIM을 활용하여 웹 기반 밀 재배관리 의사결정 지원시스템을 설계하고 구축할 것을 주장한다. 이 시스템은 일 단위 기상 환경 데이터를 수집하고 토양 수분 함량을 예측하며, 이를 바탕으로 밀의 생육 단계별 잠재 생산량을 실시간으로 예측한다. 과거, 현재, 미래의 기상 시나리오를 종합적으로 평가하여 농가가 가뭄이나 습해 등 자연재해에 선제적으로 대응하고, 관수 및 비료 처방과 같은 합리적인 영농 의사결정을 내릴 수 있도록 지원한다. 사용자 편의성을 고려한 웹 기반 대시보드를 통해 재배 환경 정보를 제공하며, 전국 기상 데이터와 필지별 토양 정보를 활용하여 타 지역에도 적용 가능하다는 장점을 가진다. 궁극적으로 본 시스템은 국내 밀 생산량 및 품질 증대에 기여하고, 향후 토양 내 질소 함량 등 추가 영향인자를 반영하여 모델을 고도화함으로써 더욱 정밀한 처방을 제공할 수 있을 것으로 기대된다.\n\n## 저자 소개\n본 연구의 저자들은 전북대학교 스마트팜학과 및 농촌건설공학과 소속의 연구진(김솔희, 장태일, 김태곤)과 학생
# ...

# %%
8. 긴 문서를 분할(Chunking)

# %%
text = open("transcription.txt", encoding="utf-8").read()

chunk_size = 500

chunks = [
    text[i:i+chunk_size]
    for i in range(0, len(text), chunk_size)
]

text
# Out:
# '안녕하세요. 어, 이 강의는 GPT API로 챗봇 만들기라는 내용을 다루는 강의입니다. 어, GPT API에 대해서 뭐 생소하신 분들도 있을 텐데, 어, 우리가 잘 알고 있는 챗 GPT, 챗 GPT를 이용해 챗 GPT 기능을 이용해서 어, 우리가 원하는 프로그램을 어떻게 만드는지에 대해서 어, 이야기할 거예요. 그래서 뭐 이런 강의들이 사실 많이 있습니다. 그래서 뭐 여러 가지들이 있는데 좀 이 강의의 특징이라고 한다면 이제 GPT로 명확한 미션을 달성하는 챗봇 프로그램을 만드는 게 사실 쉽지는 않은데 이거를 어떻게 해서 구현을 하는지 그리고 그게 왜 필요한지에 대해서 좀 이야기를 할 거고요. 어, 그 예제로 뭐 예전에 여러 가지가 될 수 있는데 여기서 예제로 하는 거는 음악 플레이리스트 동영상을 이제 자동으로 대화를 통해서 생성하는 프로그램을 만드는 거를 다루려고 합니다. 네, 그래서 프로그램이 실행되는 모습을 한번 보여 드릴게요. 그 우리가 그 만들 프로그램은 이런 식으로 이제 나타나게 될'

# %%
9. LlamaIndex Document 만들기

# %%
from llama_index.core import Document

doc = Document(
    text=text,
    metadata={
        "file":"과정기반 작물모형을 이용한 웹 기반 밀 재배관리 의사결정 지원시스템 설계 및 구축.pdf"
    }
)
doc
# Out:
# Document(id_='c441d0fe-4ebc-421b-8948-f129634ff5d2', embedding=None, metadata={'file': '과정기반 작물모형을 이용한 웹 기반 밀 재배관리 의사결정 지원시스템 설계 및 구축.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='안녕하세요. 어, 이 강의는 GPT API로 챗봇 만들기라는 내용을 다루는 강의입니다. 어, GPT API에 대해서 뭐 생소하신 분들도 있을 텐데, 어, 우리가 잘 알고 있는 챗 GPT, 챗 GPT를 이용해 챗 GPT 기능을 이용해서 어, 우리가 원하는 프로그램을 어떻게 만드는지에 대해서 어, 이야기할 거예요. 그래서 뭐 이런 강의들이 사실 많이 있습니다. 그래서 뭐 여러 가지들이 있는데 좀 이 강의의 특징이라고 한다면 이제 GPT로 명확한 미션을 달성하는 챗봇 프로그램을 만드는 게 사실 쉽지는 않은데 이거를 어떻게 해서 구현을 하는지 그리고 그게 왜 필요한지에 대해서 좀 이야기를 할 거고요. 어, 그 예제로 뭐 예전에 여러 가지가 될 수 있는데 여기서 예제로 하는 거는 음악 플레이리스트 동영상을 이제 자동으로 대화를 통해서 생성하는 프로그램을 만드는 거를 다루려고 합니다. 네, 그래서 프로그램이 실행되는 모습을 한번 보여 드릴게요. 그 우리가 그 만들 프로그램은 이런 식으로 이제 나타나게 될', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'
# ...

# %%
10.Embedding을 위한 전처리

# %%
from llama_index.core import Document

text = """
우리 회사의 근무시간은 오전 9시부터 오후 6시입니다.
점심시간은 12시부터 1시입니다.
"""

documents = [
    Document(text=text)
]

# %%
from llama_index.core.node_parser import SentenceSplitter

splitter = SentenceSplitter(
    chunk_size=512,
    chunk_overlap=50
)

nodes = splitter.get_nodes_from_documents(documents)
nodes
# Out:
# [TextNode(id_='ca3ba5f9-babc-4057-b6db-e8df6e2ad328', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e795ba37-c6ab-46e5-9e23-dab783418ed1', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='a3b368461041b7be6dbd310d811a2c2b5cfa5e826e76f3c66b8934cfa1cc759b')}, metadata_template='{key}: {value}', metadata_separator='\n', text='우리 회사의 근무시간은 오전 9시부터 오후 6시입니다.\n점심시간은 12시부터 1시입니다.', mimetype='text/plain', start_char_idx=1, end_char_idx=50, text_template='{metadata_str}\n\n{content}')]
