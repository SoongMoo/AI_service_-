# %% [raw]
# LlamaIndex는 GPT 같은 대규모 언어 모델(LLM)에 내가 가진 고유의 데이터(문서, PDF, DB 등)를 연결하여 답변을 생성할 수 있도록 도와주는 강력한 프레임워크입니다.
# PDF
# Word
# PPT
# Excel
# CSV
# JSON
# HTML
# Markdown
# 웹사이트
# Notion
# Confluence
# Slack
# Github
# Google Drive
# Dropbox
# SQL
# PostgreSQL
# MySQL
# Oracle
# MongoDB
# Redis
# S3

# %%
LangChain -> Agent -> LlamaIndex -> 데이터 검색 -> Gemini의 순으로 실행이 된다.

# %% [markdown]
# ### LlamaIndex의 핵심 내부구조
# 문서 -> Document -> Chunk -> Embedding -> Vector Store -> Retriever -> LLM

# %% [markdown]
# ### LlamaIndex는 특히 다음과 같은 작업에서 강점
# - RAG 시스템 구축
# - 기업 문서 질의응답
# - PDF 기반 챗봇
# - 사내 위키 검색
# - 데이터베이스 질의 지원
# - 로그 분석
# - 코드 저장소 기반 질의응답
# - 다수의 문서를 대상으로 한 의미 기반 검색

# %% [raw]
# 최근 활용 방식
# 사용자 질문 -> LangGraph (대화 흐름, 상태 관리) -> LlamaIndex(문서 검색, RAG) -> Gemini / GPT / Llama(답변 생성)
# LangGraph(또는 LangChain)가 전체 애플리케이션의 흐름을 제어하고, LlamaIndex는 필요한 문서나 데이터를 찾아 LLM에 제공하는 역할을 맡는 구조입니다

# %% [raw]
# 1. 사전 준비 및 라이브러리 설치

# %%
# %pip install llama-index
# %pip install pypdf
# Out:
# Requirement already satisfied: llama-index in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.14.23)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.23 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index) (0.14.23)
# Requirement already satisfied: llama-index-embeddings-openai<0.7,>=0.6.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index) (0.6.0)
# Requirement already satisfied: llama-index-llms-openai<0.8,>=0.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index) (0.7.9)
# Requirement already satisfied: nltk>=3.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index) (3.9.4)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (3.14.1)
# Requirement already satisfied: aiosqlite in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (2.4.4)
# Requirement already satisfied: dataclasses-json in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (2026.4.0)
# Requirement already satisfied: httpx in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (2.22.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (3.6.1)
# Requirement already satisfied: numpy in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (10.4.0)
# Requirement already satisfied: platformdirs in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (4.10.0)
# Requirement already satisfied: pydantic>=2.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (2.13.4)
# Requirement already satisfied: pyyaml>=6.0.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (2.34.2)
# Requirement already satisfied: setuptools>=80.9.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (82.0.1)
# Requirement already satisfied: sqlalchemy>=1.4.49 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.23->llama-index) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (0.13.0)
# Requirement already satisfied: tinytag>=2.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (4.68.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15.0,>=0.14.23->llama-index) (2.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.23->llama-index) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.23->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.23->llama-index) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.23->llama-index) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.23->llama-index) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.23->llama-index) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.23->llama-index) (1.24.2)
# Requirement already satisfied: griffe in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (2.1.0)
# Requirement already satisfied: jinja2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (3.1.6)
# Requirement already satisfied: openai>=1.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (2.44.0)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (0.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (0.16.0)
# Requirement already satisfied: sniffio in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (3.18)
# Requirement already satisfied: certifi in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx->llama-index-core<0.15.0,>=0.14.23->llama-index) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx->llama-index-core<0.15.0,>=0.14.23->llama-index) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.15.0,>=0.14.23->llama-index) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (0.4.2)
# Requirement already satisfied: colorama in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.15.0,>=0.14.23->llama-index) (0.4.6)
# Requirement already satisfied: click in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index) (8.4.2)
# Requirement already satisfied: joblib in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index) (2026.5.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (2.7.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.23->llama-index) (3.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.23->llama-index) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15.0,>=0.14.23->llama-index) (26.2)
# Requirement already satisfied: griffecli==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (2.1.0)
# Requirement already satisfied: griffelib==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.23->llama-index) (3.0.3)
# Requirement already satisfied: pypdf in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (6.14.2)

# %%
2. LlamaIndex가 PDF를 Document로 변환

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader("./data").load_data()

print("문서 개수 :", len(documents))

print(documents[0].text[:1000])
# Out:
# 문서 개수 : 5
# %PDF-1.7
# %
# 1 0 obj
# <</Type/Catalog/Pages 2 0 R/Lang(de) /StructTreeRoot 35 0 R/MarkInfo<</Marked true>>/Metadata 493 0 R/ViewerPreferences 494 0 R>>
# endobj
# 2 0 obj
# <</Type/Pages/Count 4/Kids[ 3 0 R 21 0 R 25 0 R 32 0 R] >>
# endobj
# 3 0 obj
# <</Type/Page/Parent 2 0 R/Resources<</XObject<</Image5 5 0 R/Image7 7 0 R>>/ExtGState<</GS6 6 0 R/GS11 11 0 R>>/Font<</F1 9 0 R/F2 12 0 R/F3 14 0 R/F4 19 0 R>>/ProcSet[/PDF/Text/ImageB/ImageC/ImageI] >>/MediaBox[ 0 0 595.32 841.92] /Contents 4 0 R/Group<</Type/Group/S/Transparency/CS/DeviceRGB>>/Tabs/S/StructParents 0>>
# endobj
# 4 0 obj
# <</Filter/FlateDecode/Length 4882>>
# stream
# ~7U`a`l }샬Ύ[R'!Y4]MqK*X$dU.4ۢ?pf+ʻj|^\?mO~SfR޾\|Ju{zIF,KY,Lxqȃ\"hӓ_lN'?=*ϧ''f|[v<?II"`!OHaCb"y#1u!ѝ싈sd!|#5P#0OFĲ NDY$C.k3
# zzy$>Ӝ)hQ%ydH,Ld5){es>F(`Z|>O4{}Wb\ߊ:XlFSn%"
# YY<d/U"\NDnEHI?'ߘ_rK_q)"+%xuN]GB7/Sew23G;ﺭ̂79(o|ϯG
# NbDWiAbn|9=<+U4i]Ɓow$eR@ly0}z9CCOt9AzN&/jXԛ,|߸`a,WXsqf\9Uq.

# %%
3. Metadata 확인

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader("./data").load_data()

for doc in documents:
    print(doc.metadata)
# Out:
# {'file_path': 'D:\\llm\\LLM\\data\\company_policy.pdf', 'file_name': 'company_policy.pdf', 'file_type': 'application/pdf', 'file_size': 351965, 'creation_date': '2026-07-02', 'last_modified_date': '2026-07-02'}
# {'file_path': 'D:\\llm\\LLM\\data\\employee.csv', 'file_name': 'employee.csv', 'file_type': 'application/vnd.ms-excel', 'file_size': 139, 'creation_date': '2026-07-02', 'last_modified_date': '2026-07-02'}
# {'file_path': 'D:\\llm\\LLM\\data\\etch_error_guide.txt', 'file_name': 'etch_error_guide.txt', 'file_type': 'text/plain', 'file_size': 2315, 'creation_date': '2026-07-02', 'last_modified_date': '2026-07-02'}
# {'file_path': 'D:\\llm\\LLM\\data\\safety_rules.txt', 'file_name': 'safety_rules.txt', 'file_type': 'text/plain', 'file_size': 1494, 'creation_date': '2026-07-02', 'last_modified_date': '2026-07-02'}
# {'file_path': 'D:\\llm\\LLM\\data\\회사취업규칙.pdf', 'file_name': '회사취업규칙.pdf', 'file_type': 'application/pdf', 'file_size': 3573745, 'creation_date': '2026-07-02', 'last_modified_date': '2026-07-02'}

# %%
4. Gemini 연결

# %%
# %pip install llama-index-llms-google-genai  llama-index-embeddings-google

# %pip install llama-index-llms-google-genai
# %pip install llama-index-embeddings-google
# Out:
# Requirement already satisfied: llama-index-llms-google-genai in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.9.5)
# Requirement already satisfied: llama-index-embeddings-google in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.4.2)
# Requirement already satisfied: google-genai<3,>=1.52.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-llms-google-genai) (2.10.0)
# Requirement already satisfied: llama-index-core<0.15,>=0.14.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-llms-google-genai) (0.14.23)
# Requirement already satisfied: pillow>=10.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-llms-google-genai) (10.4.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (4.14.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.55.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (49.0.0)
# Requirement already satisfied: certifi in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.16.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.14.1)
# Requirement already satisfied: aiosqlite in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.4.4)
# Requirement already satisfied: dataclasses-json in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2026.4.0)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.22.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.6.1)
# Requirement already satisfied: nltk>=3.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.9.4)
# Requirement already satisfied: numpy in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.26.4)
# Requirement already satisfied: platformdirs in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (4.10.0)
# Requirement already satisfied: pyyaml>=6.0.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (6.0.3)
# Requirement already satisfied: setuptools>=80.9.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (82.0.1)
# Requirement already satisfied: sqlalchemy>=1.4.49 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.0.51)
# Requirement already satisfied: tiktoken>=0.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.13.0)
# Requirement already satisfied: tinytag>=2.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (4.68.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.9.0)
# Requirement already satisfied: wrapt in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.24.2)
# Requirement already satisfied: griffe in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.1.0)
# Requirement already satisfied: jinja2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.4.6)
# Requirement already satisfied: google-generativeai<0.6,>=0.5.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-embeddings-google) (0.5.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.6.4)
# Requirement already satisfied: google-api-core in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.30.3)
# Requirement already satisfied: google-api-python-client in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.198.0)
# Requirement already satisfied: protobuf in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (4.25.9)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-ai-generativelanguage==0.6.4->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (1.28.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (1.75.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (1.81.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (1.62.3)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (3.0)
# Requirement already satisfied: click in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (8.4.2)
# Requirement already satisfied: joblib in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2026.5.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (26.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-python-client->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.32.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-python-client->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-python-client->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (3.3.2)
# Requirement already satisfied: griffecli==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.1.0)
# Requirement already satisfied: griffelib==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.0.3)
# Requirement already satisfied: llama-index-llms-google-genai in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.9.5)
# Requirement already satisfied: google-genai<3,>=1.52.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-llms-google-genai) (2.10.0)
# Requirement already satisfied: llama-index-core<0.15,>=0.14.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-llms-google-genai) (0.14.23)
# Requirement already satisfied: pillow>=10.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-llms-google-genai) (10.4.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (4.14.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.55.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.52.0->llama-index-llms-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (49.0.0)
# Requirement already satisfied: certifi in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.16.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.14.1)
# Requirement already satisfied: aiosqlite in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.4.4)
# Requirement already satisfied: dataclasses-json in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2026.4.0)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.22.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.6.1)
# Requirement already satisfied: nltk>=3.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.9.4)
# Requirement already satisfied: numpy in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.26.4)
# Requirement already satisfied: platformdirs in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (4.10.0)
# Requirement already satisfied: pyyaml>=6.0.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (6.0.3)
# Requirement already satisfied: setuptools>=80.9.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (82.0.1)
# Requirement already satisfied: sqlalchemy>=1.4.49 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.0.51)
# Requirement already satisfied: tiktoken>=0.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.13.0)
# Requirement already satisfied: tinytag>=2.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (4.68.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.9.0)
# Requirement already satisfied: wrapt in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.24.2)
# Requirement already satisfied: griffe in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.1.0)
# Requirement already satisfied: jinja2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (3.0)
# Requirement already satisfied: click in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (8.4.2)
# Requirement already satisfied: joblib in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2026.5.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.52.0->llama-index-llms-google-genai) (0.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (26.2)
# Requirement already satisfied: griffecli==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.1.0)
# Requirement already satisfied: griffelib==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-google-genai) (3.0.3)
# Requirement already satisfied: llama-index-embeddings-google in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.4.2)
# Requirement already satisfied: google-generativeai<0.6,>=0.5.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-embeddings-google) (0.5.4)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-embeddings-google) (0.14.23)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.6.4)
# Requirement already satisfied: google-api-core in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.30.3)
# Requirement already satisfied: google-api-python-client in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.198.0)
# Requirement already satisfied: google-auth>=2.15.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.55.1)
# Requirement already satisfied: protobuf in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (4.25.9)
# Requirement already satisfied: pydantic in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.13.4)
# Requirement already satisfied: tqdm in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (4.68.3)
# Requirement already satisfied: typing-extensions in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-ai-generativelanguage==0.6.4->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (1.28.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.34.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (1.81.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (1.62.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (49.0.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (3.14.1)
# Requirement already satisfied: aiosqlite in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2.4.4)
# Requirement already satisfied: dataclasses-json in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2026.4.0)
# Requirement already satisfied: httpx in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2.22.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (3.6.1)
# Requirement already satisfied: nltk>=3.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (3.9.4)
# Requirement already satisfied: numpy in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (10.4.0)
# Requirement already satisfied: platformdirs in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (4.10.0)
# Requirement already satisfied: pyyaml>=6.0.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (6.0.3)
# Requirement already satisfied: setuptools>=80.9.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (82.0.1)
# Requirement already satisfied: sqlalchemy>=1.4.49 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (0.13.0)
# Requirement already satisfied: tinytag>=2.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2.2.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (0.9.0)
# Requirement already satisfied: wrapt in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.24.2)
# Requirement already satisfied: griffe in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2.1.0)
# Requirement already satisfied: jinja2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (0.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2026.6.17)
# Requirement already satisfied: colorama in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (3.0)
# Requirement already satisfied: click in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (8.4.2)
# Requirement already satisfied: joblib in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2026.5.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.6.3)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.4.2)
# Requirement already satisfied: greenlet>=1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (3.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (26.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-python-client->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.32.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-python-client->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-api-python-client->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai<0.6,>=0.5.2->llama-index-embeddings-google) (3.3.2)
# Requirement already satisfied: griffecli==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2.1.0)
# Requirement already satisfied: griffelib==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (2.1.0)
# Requirement already satisfied: anyio in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (4.14.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google) (3.0.3)

# %%
from google import genai

client = genai.Client(api_key="your_api_key")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="연차의 의미를 설명하세요."
)

print(response.text)
# Out:
# '연차'는 정식 명칭으로는 **'연차유급휴가(年次有給休暇)'** 라고 하며, 근로기준법에 따라 근로자에게 주어지는 법정 휴가입니다. 쉽게 말해, **근로자가 일정한 근로 기간을 채우면 유급으로 쉴 수 있는 권리**를 의미합니다.
#
# 연차의 의미를 좀 더 자세히 설명하면 다음과 같습니다.
#
# 1.  **법적 권리 (근로기준법):**
#     *   연차는 회사의 시혜나 배려가 아닌, 근로기준법에 명시된 **근로자의 기본적인 권리**입니다. 즉, 법이 정한 요건을 충족하면 누구나 부여받을 수 있습니다.
#
# 2.  **유급 휴가:**
#     *   '유급(有給)'이라는 말처럼, 연차를 사용하여 쉬는 동안에도 **정상적인 임금(급여)이 지급**됩니다. 쉬는 날만큼 월급이 깎이지 않는다는 의미입니다.
#
# 3.  **목적 (휴식 및 재충전):**
#     *   근로자의 육체적, 정신적 피로를 해소하고 재충전의 기회를 제공하여 건강한 삶과 근무 능률 향상을 도모하는 것이 주된 목적입니다. 개인적인 용무(경조사, 병원 진료, 여행 등)에 활용할 수도 있습니다.
#
# 4.  **부여 기준 및 일수:**
#     *   **1년 미만 근로자:** 최초 1년간 80% 이상 출근하면 1개월 개근 시 1일의 유급휴가가 발생합니다 (최대 11일).
#     *   **1년 이상 근로자:** 1년간 80% 이상 출근하면 15일의 유급휴가가 발생합니다.
#     *   **장기 근속자:** 3년 이상 계속 근로한 근로자에게는 최초 15일에 2년마다 1일씩 가산하여 지급합니다 (총 25일이 한도).
#
# 5.  **사용 원칙:**
#     *   근로자가 원하는 시기에 연차 사용을 청구할 수 있으며, 회사는 사업 운영에 막대한 지장이 없는 한 이를 허용해야 합니다.
#
# 6.  **미사용 연차 처리 (연차수당/연차사용촉진):**
#     *   발생한 연차를 사용하지 못하고 소멸 기한이 지나면, 원칙적으로는 **미사용 연차에 대한 수당(연차수당)**을 지급해야 합니다.
#     *   다만, 회사가 근로기준법에서 정한 절차에 따라 **'연차휴가 사용 촉진 제도'**를 시행했음에도 근로자가 연차를 사용하지 않은 경우에는 연차수당 지급 의무가 면제될 수 있습니다.
#
# **요약하자면,** 연차는 근로자가 업무에서 벗어나 쉬고 재충전할 수 있도록 법적으로 보장된 '월급이 나오는 휴가'이며, 근로자의 건강과 삶의 질, 그리고 업무 생산성 향상에 중요한 역할을 합니다.

# %%
import google.generativeai as genai
print(genai.__version__)
# Out:
# 0.5.4

# %%
# %pip install -U llama-index-embeddings-huggingface
# Out:
# Requirement already satisfied: llama-index-embeddings-google-genai in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.5.1)
# Requirement already satisfied: google-genai<3,>=1.24.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-embeddings-google-genai) (2.10.0)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-embeddings-google-genai) (0.14.23)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (4.14.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (2.55.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (49.0.0)
# Requirement already satisfied: certifi in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (0.16.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.14.1)
# Requirement already satisfied: aiosqlite in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.4.4)
# Requirement already satisfied: dataclasses-json in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2026.4.0)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.22.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.6.1)
# Requirement already satisfied: nltk>=3.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.9.4)
# Requirement already satisfied: numpy in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (10.4.0)
# Requirement already satisfied: platformdirs in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (4.10.0)
# Requirement already satisfied: pyyaml>=6.0.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (6.0.3)
# Requirement already satisfied: setuptools>=80.9.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (82.0.1)
# Requirement already satisfied: sqlalchemy>=1.4.49 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.0.51)
# Requirement already satisfied: tiktoken>=0.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.13.0)
# Requirement already satisfied: tinytag>=2.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (4.68.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.9.0)
# Requirement already satisfied: wrapt in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.24.2)
# Requirement already satisfied: griffe in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.1.0)
# Requirement already satisfied: jinja2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (3.0)
# Requirement already satisfied: click in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (8.4.2)
# Requirement already satisfied: joblib in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2026.5.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3,>=1.24.0->llama-index-embeddings-google-genai) (0.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (26.2)
# Requirement already satisfied: griffecli==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.1.0)
# Requirement already satisfied: griffelib==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai) (3.0.3)

# %%
# %pip install nest_asyncio

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import Settings
from llama_index.llms.google_genai import GoogleGenAI
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

GOOGLE_API_KEY = "your_api_key"
 
Settings.llm = GoogleGenAI(
    model="gemini-2.5-flash",
    api_key=GOOGLE_API_KEY,
    temperature=0.1
)

Settings.embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-m3"
)

response = Settings.llm.complete("연차의 의미를 설명하세요.")

print(response.text)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# **연차(年次)**는 '연차 유급휴가'의 줄임말로, 근로기준법에 따라 근로자가 1년간 소정의 근로를 제공했을 때 부여받는 **유급휴가**를 의미합니다.
#
# 쉽게 말해, **"일정 기간 일한 근로자에게 법적으로 주어지는, 급여가 지급되는 쉬는 날"** 입니다.
#
# **연차의 주요 의미와 특징은 다음과 같습니다:**
#
# 1.  **근로자의 권리 보장:**
#     *   **휴식권 보장:** 근로자의 신체적, 정신적 피로를 회복하고 건강을 유지할 수 있도록 법적으로 보장된 권리입니다.
#     *   **생활권 보장:** 휴가를 사용하더라도 임금이 지급되므로, 근로자가 경제적 부담 없이 휴식을 취하거나 개인적인 용무를 처리할 수 있게 합니다.
#
# 2.  **법적 근거:**
#     *   대한민국 **근로기준법 제60조**에 명시되어 있으며, 근로자의 근로 기간과 출근율에 따라 연차 발생 기준과 일수가 정해져 있습니다.
#
# 3.  **발생 기준 및 일수:**
#     *   **1년 이상 근로자:** 1년간 80% 이상 출근한 근로자에게 15일의 유급휴가가 발생합니다.
#     *   **1년 미만 근로자 또는 1년간 80% 미만 출근 근로자:** 1개월 개근 시 1일의 유급휴가가 발생합니다.
#     *   **가산 휴가:** 최초 1년을 초과하는 계속 근로 연수 2년마다 1일씩 가산되며, 총 25일을 한도로 합니다. (예: 3년차에 16일, 5년차에 17일 등)
#
# 4.  **사용 원칙:**
#     *   근로자가 원하는 시기에 자유롭게 사용할 수 있는 것이 원칙입니다.
#     *   다만, 사업 운영에 막대한 지장이 있는 경우 사용자는 그 시기를 변경할 수 있습니다.
#
# 5.  **미사용 연차 처리:**
#     *   연차는 발생일로부터 1년 이내에 사용해야 하며, 사용하지 못한 연차에 대해서는 '연차수당'으로 보상받을 수 있습니다.
#     *   그러나 사용자가 '연차 사용 촉진 제도'를 통해 근로자에게 연차 사용을 적극적으로 권유했음에도 근로자가 사용하지 않은 경우에는 연차수당 지급 의무가 면제될 수 있습니다.
#
# 6.  **목적 및 효과:**
#     *   **근로자 측면:** 피로 해소, 스트레스 감소, 개인적인 용무 처리, 여가 활동, 가족 행사 참여 등을 통해 삶의 질 향상 및 워라밸(Work-Life Balance) 실현.
#     *   **기업 측면:** 근로자의 사기 진작, 업무 효율성 증대, 장기적인 근속 유도, 이직률 감소 등 긍정적인 효과를 가져올 수 있습니다.
#
# 결론적으로 연차는 근로자의 기본적인 권리이자 건강하고 생산적인 근로 생활을 위한 필수적인 제도이며, 근로자와 사용자 모두에게 긍정적인 영향을 미치는 중요한 의미를 가집니다.

# %%
5. PDF → Index 생성

# %%
from llama_index.core import (
    SimpleDirectoryReader,
    VectorStoreIndex
)
from llama_index.core.node_parser import SentenceSplitter

# 1. 문서 읽기
documents = SimpleDirectoryReader("./data").load_data()

# 2. 원하는 크기(512)로 텍스트 쪼개기
splitter = SentenceSplitter(
    chunk_size=512,
    chunk_overlap=50
)

nodes = splitter.get_nodes_from_documents(documents)

# 3. Index 생성
index = VectorStoreIndex(nodes)

print("원하는 크기로 Index 생성 완료!")
# Out:
# 원하는 크기로 Index 생성 완료!

# %%
6. Query Engine 생성

# %%
# %pip install -U sentence-transformers

# %%
query_engine = index.as_query_engine()

response = query_engine.query(
    "연차는 몇 일인가요?"
)

print(response)

# %%
#7. Gemini 명시적으로 연결

# %%
# from llama_index.core import (
#     SimpleDirectoryReader,
#     VectorStoreIndex
# )

# documents = SimpleDirectoryReader(
#     "./data"
# ).load_data()

# index = VectorStoreIndex.from_documents(
#     documents
# )

# query_engine = index.as_query_engine()

# response = query_engine.query(
#     "연차는 몇 일인가요?"
# )

# print(response)

# %%
8. 출처(Source) 확인

# %%
print("\n출처")

for node in response.source_nodes:
    print(
        node.metadata["file_name"]
    )

# %%
질문
# 출장비는 얼마인가요?

# 육아휴직은 며칠인가요?

# 경조사 지원금은?

# %%
9. 여러 PDF 검색

# %%
documents = SimpleDirectoryReader(
    "./data"
).load_data()

# %%
10. Index 저장

# %%
index.storage_context.persist(
    persist_dir="./storage"
)

# %%
###############

# %%
11. 저장된 Index 재사용

# %%
from llama_index.core import (
    StorageContext,
    load_index_from_storage
)

storage_context = StorageContext.from_defaults(
    persist_dir="./storage"
)

index = load_index_from_storage(
    storage_context
)

query_engine = index.as_query_engine()

response = query_engine.query(
    "출장비는 얼마인가요?"
)

print(response)

# %%
12. 콘솔 챗봇 완성

# %%
while True:

    question = input("\n질문 : ")

    if question == "exit":
        break

    response = query_engine.query(
        question
    )

    print("\n답변")
    print(response)

    print("\n출처")

    for node in response.source_nodes:
        print(
            node.metadata["file_name"]
        )

# %%
# !pip install llama-index llama-index-llms-gemini llama-index-embeddings-gemini

# %%
# !pip install llama-index-embeddings-huggingface 
### 파이썬 코드에서 임베딩 설정을 다국어 성능이 좋은 모델로 설치합니다.
# Out:
# Requirement already satisfied: llama-index-embeddings-huggingface in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.7.0)
# Requirement already satisfied: huggingface-hub>=0.19.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.23.5)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-embeddings-huggingface) (0.14.23)
# Requirement already satisfied: sentence-transformers>=2.6.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-embeddings-huggingface) (5.6.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.14.1)
# Requirement already satisfied: aiosqlite in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.4.4)
# Requirement already satisfied: dataclasses-json in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2026.4.0)
# Requirement already satisfied: httpx in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.22.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.6.1)
# Requirement already satisfied: nltk>=3.9.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.9.4)
# Requirement already satisfied: numpy in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (10.4.0)
# Requirement already satisfied: platformdirs in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (4.10.0)
# Requirement already satisfied: pydantic>=2.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.13.4)
# Requirement already satisfied: pyyaml>=6.0.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.34.2)
# Requirement already satisfied: setuptools>=80.9.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (82.0.1)
# Requirement already satisfied: sqlalchemy>=1.4.49 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.13.0)
# Requirement already satisfied: tinytag>=2.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (4.68.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.24.2)
# Requirement already satisfied: griffe in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.1.0)
# Requirement already satisfied: jinja2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.5.0)
# Requirement already satisfied: colorama in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.4.6)
# Requirement already satisfied: idna>=2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.18)
# Requirement already satisfied: filelock in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.29.4)
# Requirement already satisfied: packaging>=20.9 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (26.2)
# Requirement already satisfied: minijinja>=1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.21.0)
# Requirement already satisfied: click in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (8.4.2)
# Requirement already satisfied: joblib in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2026.5.9)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2026.6.17)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.41.2)
# Requirement already satisfied: torch>=1.11.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.3.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.17.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.8.0)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.6.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.5.3)
# Requirement already satisfied: sympy in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.14.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2021.13.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.26.2)
# Requirement already satisfied: griffecli==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.1.0)
# Requirement already satisfied: griffelib==2.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (2.1.0)
# Requirement already satisfied: anyio in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (4.14.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-huggingface) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)

# %%
import os
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Settings, PromptTemplate
from llama_index.llms.gemini import Gemini
from llama_index.embeddings.gemini import GeminiEmbedding
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# 1. API 키 설정 (Google AI Studio 발급 키)
os.environ["GOOGLE_API_KEY"] = "your_api_key"

def main():
    # 2. Gemini 모델 설정 (Flash 모델 및 내장 임베딩 사용)
    Settings.llm = Gemini(model="models/gemini-2.5-flash", temperature=0.2)
    Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-m3")

    # 3. 데이터 로드 및 인덱싱
    print("🔧 사내 장비 매뉴얼 데이터를 로드하고 인덱싱하는 중...")
    documents = SimpleDirectoryReader("data").load_data()
    index = VectorStoreIndex.from_documents(documents)

    # 4. 답변 품질을 높이기 위한 커스텀 프롬프트 템플릿 정의
    # (장비 정비사처럼 전문적이고 안전을 강조하는 어조로 유도)
    qa_prompt_tmpl_str = (
        "아래 제공된 장비 매뉴얼 정보를 바탕으로 작업자의 질문에 친절하고 정확하게 답해 주세요.\n"
        "만약 정보가 부족하다면 억지로 답변을 지어내지 말고 '해당 정보는 매뉴얼에 포함되어 있지 않습니다'라고 답하세요.\n"
        "특히 안전 수칙(보호구, 전원 차단 등)과 관련된 내용이 있다면 답변에서 강력히 강조해 주세요.\n\n"
        "---------------------\n"
        "{context_str}\n"
        "---------------------\n"
        "질문: {query_str}\n"
        "답변 (전문 엔지니어 톤으로):"
    )
    qa_prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str)

    # 5. 쿼리 엔진 생성 및 프롬프트 적용
    query_engine = index.as_query_engine()
    query_engine.update_prompts(
        {"response_synthesizer:text_qa_template": qa_prompt_tmpl}
    )

    # 6. 현장 정비사의 시나리오 질문 테스트
    print("\n==================================================")
    question = "지금 ETCH-200 장비에 E-0402 에러가 떴어. 어떻게 조치해야 하고 부품 번호는 뭐야? 안전 조치도 같이 알려줘."
    print(f"👷 현장 정비사 질문: {question}")
    print("==================================================")

    # gemini-2.5-flash 모델이 검색된 컨텍스트를 분석하여 답변 생성
    response = query_engine.query(question)

    print("\n AI 가이드 답변:")
    print(response)

if __name__ == "__main__":
    main()

# %%
# !pip install llama-index llama-index-llms-gemini llama-index-embeddings-huggingface pypdf

# %%
import os
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Settings, PromptTemplate
from llama_index.llms.gemini import Gemini
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# 1. Gemini API 키 설정
os.environ["GOOGLE_API_KEY"] = "your_api_key"

def main():
    # 2. Gemini 2.5 Flash 및 임베딩 모델 설정
    Settings.llm = Gemini(model="models/gemini-2.5-flash", temperature=0.1)
    Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-m3")

    # 3. PDF 파일 로드 및 인덱싱
    # SimpleDirectoryReader는 폴더 내의 .pdf 파일을 자동으로 인식하고 파싱합니다.
    print("📄 data 폴더에서 PDF 문서를 읽어와 인덱싱하는 중...")
    documents = SimpleDirectoryReader("data").load_data()
    index = VectorStoreIndex.from_documents(documents)

    # 4. HR(인사팀) 스타일의 프롬프트 템플릿 설정
    hr_prompt_tmpl_str = (
        "당신은 회사의 친절한 인사팀(HR) AI 담당자입니다.\n"
        "사내 규정 PDF 문서에서 추출된 아래 정보를 바탕으로 직원의 질문에 공손하고 명확하게 답변해 주세요.\n"
        "문서에 없는 내용에 대해서는 추측해서 답변하지 말고, '인사팀 담당자에게 직접 문의해 주세요'라고 안내하세요.\n\n"
        "---------------------\n"
        "{context_str}\n"
        "---------------------\n"
        "직원 질문: {query_str}\n"
        "인사팀 AI 답변:"
    )
    hr_prompt_tmpl = PromptTemplate(hr_prompt_tmpl_str)

    # 5. 쿼리 엔진 생성 및 프롬프트 적용
    query_engine = index.as_query_engine()
    query_engine.update_prompts(
        {"response_synthesizer:text_qa_template": hr_prompt_tmpl}
    )

    # 6. 직원의 질문 시나리오 테스트
    print("\n==================================================")
    question = "올해 결혼을 하게 되었는데, 경조 휴가는 며칠이나 쓸 수 있고 지원금도 나오나요? 그리고 운동 학원비도 자기개발비로 신청 가능한지 궁금합니다."
    print(f"👤 직원 질문: {question}")
    print("==================================================")

    # PDF에서 관련 내용을 찾아 Gemini가 종합 답변 생성
    response = query_engine.query(question)
    
    print("\n HR AI 답변:")
    print(response)

if __name__ == "__main__":
    main()

# %%
2. CSV 읽기

# %%
import pandas as pd

df = pd.read_csv("./data/employee.csv")

print(df)
# Out:
#      사번   이름  부서    연봉
# 0  1001  홍길동  개발  6000
# 1  1002  김철수  인사  5200
# 2  1003  이영희  영업  5800
# 3  1004  박민수  개발  6700

# %%
3. DataFrame 확인

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사번      4 non-null      int64
#  1   이름      4 non-null      str
#  2   부서      4 non-null      str
#  3   연봉      4 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 320.0 bytes
# None

# %%
Step 4. DataFrame을 Document로 변환

# %%
from llama_index.core import Document

documents = []

for _, row in df.iterrows():

    text = f"""
    사번 : {row['사번']}
    이름 : {row['이름']}
    부서 : {row['부서']}
    연봉 : {row['연봉']}
    """

    documents.append(
        Document(text=text)
    )
print(len(documents))
print(documents)
# Out:
# 4
# <class 'pydantic._internal._model_construction.ModelMetaclass'>
# [Document(id_='feeee37d-75d8-4d65-9d19-03bbb01b84a4', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='\n    사번 : 1001\n    이름 : 홍길동\n    부서 : 개발\n    연봉 : 6000\n    ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'), Document(id_='b5fc3379-77b7-4c03-9725-387870698e63', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='\n    사번 : 1002\n    이름 : 김철수\n    부서 : 인사\n    연봉 : 5200\n    ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'), Document(id_='0c1fca4c-a676-4ae9-92d4-6a99926bf2f9', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='\n    사번 : 1003\n    이름 : 이영희\n    부서 : 영업\n    연봉 : 5800\n    ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'), Document(id_='8437c998-9a7c-4470-bb2f-d1938556311a', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='\n    사번 : 1004\n    이름 : 박민수\n    부서 : 개발\n    연봉 : 6700\n    ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]

# %%
Step 5. Document 확인

# %%
print(documents[0].text)
# Out:
#     사번 : 1001
#     이름 : 홍길동
#     부서 : 개발
#     연봉 : 6000

# %%
6. Node 생성

# %%
from llama_index.core.node_parser import SentenceSplitter

splitter = SentenceSplitter(
    chunk_size=100,
    chunk_overlap=20
)

nodes = splitter.get_nodes_from_documents(
    documents
)

print(len(nodes))
# Out:
# 4

# %%
7. Node 확인

# %%
print(nodes[0].text)
# Out:
# 사번 : 1001
#     이름 : 홍길동
#     부서 : 개발
#     연봉 : 6000

# %%
8. Gemini 연결

# %%
import os
GOOGLE_API_KEY = os.environ["GOOGLE_API_KEY"] = "your_api_key"

from llama_index.core import Settings
from llama_index.llms.google_genai import GoogleGenAI

Settings.llm = GoogleGenAI(
    model="gemini-2.5-flash",
    api_key=GOOGLE_API_KEY
)

# %%
9. Embedding 설정

# %%
Settings.embed_model = GoogleGenAIEmbedding(
    model="gemini-embedding-001",
    api_key=GOOGLE_API_KEY
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Settings.embed_model = GoogleGenAIEmbedding(
#       2     model="gemini-embedding-001",
#       3     api_key=GOOGLE_API_KEY
#       4 )
#
# NameError: name 'GoogleGenAIEmbedding' is not defined

# %%
10. Index 생성

# %%
from llama_index.core import VectorStoreIndex

index = VectorStoreIndex.from_documents(
    documents
)

# %%
11. Query Engine

# %%
query_engine = index.as_query_engine()

response = query_engine.query(
    "개발부 직원은 누구인가?"
)

print(response)

# %%
12. Source 확인

# %%
print(response.source_nodes)

# %%
13. 검색 실험 : 질문을 바꿔보게 합니다.

# %%
"연봉이 가장 높은 직원은?"
"인사부 직원은?"
"홍길동의 연봉은?"

# %%
14. Retrieval 확인

# %%
retriever = index.as_retriever()

nodes = retriever.retrieve(
    "개발부"
)

for node in nodes:
    print(node.text)

# %%
Gemini 연결하기
TXT 읽기
PDF 읽기
CSV 읽기
여러 문서 읽기
VectorStoreIndex 생성
Query Engine 만들기
Chunk Size 변경하기
Metadata 활용하기
문서 기반 챗봇 만들기
